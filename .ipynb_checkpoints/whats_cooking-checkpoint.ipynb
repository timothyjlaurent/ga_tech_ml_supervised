# %%
import numpy as np
import os
print(os.getcwd())
# %matplotlib inline  
np.random.seed(42)
# Out:
# /home/dadmin/dev/machine-learning-supervised

# %%
## loader adapted from https://kaggle2.blob.core.windows.net/forum-message-attachments/92129/2925/cook.py?sv=2012-02-12&se=2015-09-17T07%3A33%3A08Z&sr=b&sp=r&sig=L0O70df70vhU2ZTBu%2FanG9mafzDdeiVhFaAx0dkscfc%3D

import json
from pandas import DataFrame
from collections import OrderedDict
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np




with open('./data/whats_cookin/train.json') as train_f:
    train_data = json.load(train_f)
    
train_X = [' '.join(e['ingredients']) for e in train_data]
train_Y = [e['cuisine'] for e in train_data]

le = LabelEncoder()
ngram_vectorizer = CountVectorizer()

all_classes = le.fit_transform(train_Y)
all_inputs = ngram_vectorizer.fit_transform(train_X).toarray()

# %%
#[item for sublist in l for item in sublist]
train_X_list = [ ingredient for e in train_data for ingredient in e['ingredients'] ]
len(sorted(list(set(train_X_list))))
# Out:
# 6714

# %%
train_X_list
# Out:
# [u'romaine lettuce',
#  u'black olives',
#  u'grape tomatoes',
#  u'garlic',
#  u'pepper',
#  u'purple onion',
#  u'seasoning',
#  u'garbanzo beans',
#  u'feta cheese crumbles',
#  u'plain flour',
#  u'ground pepper',
#  u'salt',
#  u'tomatoes',
#  u'ground black pepper',
#  u'thyme',
#  u'eggs',
#  u'green tomatoes',
#  u'yellow corn meal',
#  u'milk',
#  u'vegetable oil',
#  u'eggs',
#  u'pepper',
#  u'salt',
#  u'mayonaise',
#  u'cooking oil',
#  u'green chilies',
#  u'grilled chicken breasts',
#  u'garlic powder',
#  u'yellow onion',
#  u'soy sauce',
#  u'butter',
#  u'chicken livers',
#  u'water',
#  u'vegetable oil',
#  u'wheat',
#  u'salt',
#  u'black pepper',
#  u'shallots',
#  u'cornflour',
#  u'cayenne pepper',
#  u'onions',
#  u'garlic paste',
#  u'milk',
#  u'butter',
#  u'salt',
#  u'lemon juice',
#  u'water',
#  u'chili powder',
#  u'passata',
#  u'oil',
#  u'ground cumin',
#  u'boneless chicken skinless thigh',
#  u'garam masala',
#  u'double cream',
#  u'natural yogurt',
#  u'bay leaf',
#  u'plain flour',
#  u'sugar',
#  u'butter',
#  u'eggs',
#  u'fresh ginger root',
#  u'salt',
#  u'ground cinnamon',
#  u'milk',
#  u'vanilla extract',
#  u'ground ginger',
#  u'powdered sugar',
#  u'baking powder',
#  u'olive oil',
#  u'salt',
#  u'medium shrimp',
#  u'pepper',
#  u'garlic',
#  u'chopped cilantro',
#  u'jalapeno chilies',
#  u'flat leaf parsley',
#  u'skirt steak',
#  u'white vinegar',
#  u'sea salt',
#  u'bay leaf',
#  u'chorizo sausage',
#  u'sugar',
#  u'pistachio nuts',
#  u'white almond bark',
#  u'flour',
#  u'vanilla extract',
#  u'olive oil',
#  u'almond extract',
#  u'eggs',
#  u'baking powder',
#  u'dried cranberries',
#  u'olive oil',
#  u'purple onion',
#  u'fresh pineapple',
#  u'pork',
#  u'poblano peppers',
#  u'corn tortillas',
#  u'cheddar cheese',
#  u'ground black pepper',
#  u'salt',
#  u'iceberg lettuce',
#  u'lime',
#  u'jalapeno chilies',
#  u'chopped cilantro fresh',
#  u'chopped tomatoes',
#  u'fresh basil',
#  u'garlic',
#  u'extra-virgin olive oil',
#  u'kosher salt',
#  u'flat leaf parsley',
#  u'pimentos',
#  u'sweet pepper',
#  u'dried oregano',
#  u'olive oil',
#  u'garlic',
#  u'sharp cheddar cheese',
#  u'pepper',
#  u'swiss cheese',
#  u'provolone cheese',
#  u'canola oil',
#  u'mushrooms',
#  u'black olives',
#  u'sausages',
#  u'low sodium soy sauce',
#  u'fresh ginger',
#  u'dry mustard',
#  u'green beans',
#  u'white pepper',
#  u'sesame oil',
#  u'scallions',
#  u'canola oil',
#  u'sugar',
#  u'Shaoxing wine',
#  u'garlic',
#  u'ground turkey',
#  u'water',
#  u'crushed red pepper flakes',
#  u'corn starch',
#  u'Italian parsley leaves',
#  u'walnuts',
#  u'hot red pepper flakes',
#  u'extra-virgin olive oil',
#  u'fresh lemon juice',
#  u'trout fillet',
#  u'garlic cloves',
#  u'chipotle chile',
#  u'fine sea salt',
#  u'flat leaf parsley',
#  u'ground cinnamon',
#  u'fresh cilantro',
#  u'chili powder',
#  u'ground coriander',
#  u'kosher salt',
#  u'ground black pepper',
#  u'garlic',
#  u'plum tomatoes',
#  u'avocado',
#  u'lime juice',
#  u'flank steak',
#  u'salt',
#  u'ground cumin',
#  u'black pepper',
#  u'olive oil',
#  u'crushed red pepper flakes',
#  u'onions',
#  u'fresh parmesan cheese',
#  u'butter',
#  u'all-purpose flour',
#  u'fat free less sodium chicken broth',
#  u'chopped fresh chives',
#  u'gruyere cheese',
#  u'ground black pepper',
#  u'bacon slices',
#  u'gnocchi',
#  u'fat free milk',
#  u'cooking spray',
#  u'salt',
#  u'tumeric',
#  u'vegetable stock',
#  u'tomatoes',
#  u'garam masala',
#  u'naan',
#  u'red lentils',
#  u'red chili peppers',
#  u'onions',
#  u'spinach',
#  u'sweet potatoes',
#  u'greek yogurt',
#  u'lemon curd',
#  u'confectioners sugar',
#  u'raspberries',
#  u'italian seasoning',
#  u'broiler-fryer chicken',
#  u'mayonaise',
#  u'zesty italian dressing',
#  u'sugar',
#  u'hot chili',
#  u'asian fish sauce',
#  u'lime juice',
#  u'soy sauce',
#  u'vegetable oil',
#  u'red bell pepper',
#  u'chicken broth',
#  u'yellow squash',
#  u'garlic chili sauce',
#  u'sliced green onions',
#  u'broccolini',
#  u'salt',
#  u'fresh lime juice',
#  u'cooked rice',
#  u'chicken breasts',
#  u'corn starch',
#  u'pork loin',
#  u'roasted peanuts',
#  u'chopped cilantro fresh',
#  u'hoisin sauce',
#  u'creamy peanut butter',
#  u'chopped fresh mint',
#  u'thai basil',
#  u'rice',
#  u'medium shrimp',
#  u'water',
#  u'rice noodles',
#  u'beansprouts',
#  u'roma tomatoes',
#  u'kosher salt',
#  u'purple onion',
#  u'jalapeno chilies',
#  u'lime',
#  u'chopped cilantro',
#  u'low-fat mayonnaise',
#  u'pepper',
#  u'salt',
#  u'baking potatoes',
#  u'eggs',
#  u'spicy brown mustard',
#  u'sesame seeds',
#  u'red pepper',
#  u'yellow peppers',
#  u'water',
#  u'extra firm tofu',
#  u'broccoli',
#  u'soy sauce',
#  u'orange bell pepper',
#  u'arrowroot powder',
#  u'fresh ginger',
#  u'sesame oil',
#  u'red curry paste',
#  u'marinara sauce',
#  u'flat leaf parsley',
#  u'olive oil',
#  u'linguine',
#  u'capers',
#  u'crushed red pepper flakes',
#  u'olives',
#  u'lemon zest',
#  u'garlic',
#  u'sugar',
#  u'lo mein noodles',
#  u'salt',
#  u'chicken broth',
#  u'light soy sauce',
#  u'flank steak',
#  u'beansprouts',
#  u'dried black mushrooms',
#  u'pepper',
#  u'chives',
#  u'oyster sauce',
#  u'dark soy sauce',
#  u'peanuts',
#  u'sesame oil',
#  u'cabbage',
#  u'herbs',
#  u'lemon juice',
#  u'fresh tomatoes',
#  u'paprika',
#  u'mango',
#  u'stock',
#  u'chile pepper',
#  u'onions',
#  u'red chili peppers',
#  u'oil',
#  u'ground black pepper',
#  u'butter',
#  u'sliced mushrooms',
#  u'sherry',
#  u'salt',
#  u'grated parmesan cheese',
#  u'heavy cream',
#  u'spaghetti',
#  u'chicken broth',
#  u'cooked chicken',
#  u'all-purpose flour',
#  u'green bell pepper',
#  u'egg roll wrappers',
#  u'sweet and sour sauce',
#  u'corn starch',
#  u'molasses',
#  u'vegetable oil',
#  u'oil',
#  u'soy sauce',
#  u'shredded cabbage',
#  u'garlic',
#  u'onions',
#  u'fresh ginger root',
#  u'ground pork',
#  u'carrots',
#  u'flour tortillas',
#  u'cheese',
#  u'breakfast sausages',
#  u'large eggs',
#  u'yellow corn meal',
#  u'boiling water',
#  u'butter',
#  u'fresh parmesan cheese',
#  u'sea salt',
#  u'chicken broth',
#  u'chicken breasts',
#  u'hot sauce',
#  u'red bell pepper',
#  u'potatoes',
#  u'bacon',
#  u'garlic cloves',
#  u'fresh parsley',
#  u'andouille sausage',
#  u'cajun seasoning',
#  u'peanut oil',
#  u'celery',
#  u'ground red pepper',
#  u'all-purpose flour',
#  u'shrimp',
#  u'onions',
#  u'chili powder',
#  u'crushed red pepper flakes',
#  u'garlic powder',
#  u'sea salt',
#  u'ground cumin',
#  u'onion powder',
#  u'dried oregano',
#  u'ground black pepper',
#  u'paprika',
#  u'eggs',
#  u'shallots',
#  u'firm tofu',
#  u'beansprouts',
#  u'turnips',
#  u'palm sugar',
#  u'vegetable oil',
#  u'garlic cloves',
#  u'sliced chicken',
#  u'fish sauce',
#  u'lime wedges',
#  u'roasted peanuts',
#  u'green papaya',
#  u'chile powder',
#  u'ground black pepper',
#  u'tamarind paste',
#  u'chinese chives',
#  u'olive oil',
#  u'onions',
#  u'crushed garlic',
#  u'dried oregano',
#  u'green onions',
#  u'white sugar',
#  u'dried basil',
#  u'diced tomatoes',
#  u'olive oil',
#  u'diced tomatoes',
#  u'Johnsonville Andouille Dinner Sausage',
#  u'parsley',
#  u'shrimp',
#  u'jambalaya rice mix',
#  u'worcestershire sauce',
#  u'hot pepper sauce',
#  u'creole seasoning',
#  u'olive oil',
#  u'bread slices',
#  u'great northern beans',
#  u'garlic cloves',
#  u'pepper',
#  u'shrimp',
#  u'sage leaves',
#  u'salt',
#  u'chicken broth',
#  u'cooking oil',
#  u'chinese five-spice powder',
#  u'ground black pepper',
#  u'salt',
#  u'sugar',
#  u'crushed garlic',
#  u'chicken thighs',
#  u'soy sauce',
#  u'star anise',
#  u'green onions',
#  u'cream cheese',
#  u'shredded cheddar cheese',
#  u'cayenne pepper',
#  u'chili powder',
#  u'garlic cloves',
#  u'black-eyed peas',
#  u'tortilla chips',
#  u'collard greens',
#  u'extra-virgin olive oil',
#  u'ham hock',
#  u'chicken stock',
#  u'apple cider',
#  u'freshly ground pepper',
#  u'chile powder',
#  u'bay leaves',
#  u'salt',
#  u'rib',
#  u'light brown sugar',
#  u'large garlic cloves',
#  u'cayenne pepper',
#  u'onions',
#  u'Oscar Mayer Deli Fresh Smoked Ham',
#  u'hoagie rolls',
#  u'salami',
#  u'giardiniera',
#  u'mozzarella cheese',
#  u'pepperoni',
#  u'butter',
#  u'italian seasoning',
#  u'ice cubes',
#  u'club soda',
#  u'white rum',
#  u'lime',
#  u'turbinado',
#  u'cooked chicken',
#  u'enchilada sauce',
#  u'sliced green onions',
#  u'picante sauce',
#  u'green pepper',
#  u'corn tortillas',
#  u'canned black beans',
#  u'shredded lettuce',
#  u'sour cream',
#  u'shredded cheddar cheese',
#  u'garlic cloves',
#  u'canola oil',
#  u'salmon fillets',
#  u'shallots',
#  u'cumin seed',
#  u'fresh cilantro',
#  u'salt',
#  u'curry powder',
#  u'vegetable oil',
#  u'serrano chile',
#  u'fresh ginger',
#  u'sauce',
#  u'tomatoes',
#  u'chicken breast halves',
#  u'chopped cilantro fresh',
#  u'white vinegar',
#  u'jalapeno chilies',
#  u'salt',
#  u'black pepper',
#  u'vegetable oil',
#  u'avocado',
#  u'lettuce leaves',
#  u'chopped onion',
#  u'eggs',
#  u'mandarin oranges',
#  u'water',
#  u'orange liqueur',
#  u'yellow cake mix',
#  u'frosting',
#  u'vegetable oil',
#  u'white sugar',
#  u'sugar',
#  u'salt',
#  u'fennel bulb',
#  u'water',
#  u'lemon olive oil',
#  u'grapefruit juice',
#  u'sugar',
#  u'all-purpose flour',
#  u'vegetable oil',
#  u'white cornmeal',
#  u'baking powder',
#  u'onions',
#  u'bacon drippings',
#  u'buttermilk',
#  u'butter',
#  u'crab boil',
#  u'garlic',
#  u'old bay seasoning',
#  u'cream cheese',
#  u'crawfish',
#  u'salt',
#  u'mayonaise',
#  u'white sugar',
#  u'ground black pepper',
#  u'salt',
#  u'white vinegar',
#  u'lemon juice',
#  u'sirloin',
#  u'mirin',
#  u'yellow onion',
#  u'low sodium soy sauce',
#  u'water',
#  u'corn oil',
#  u'sugar',
#  u'green onions',
#  u'glass noodles',
#  u'sake',
#  u'shiitake',
#  u'napa cabbage',
#  u'large eggs',
#  u'whipping cream',
#  u'chicken broth',
#  u'ground red pepper',
#  u'extra sharp cheddar cheese',
#  u'quickcooking grits',
#  u'hot sauce',
#  u'ground black pepper',
#  u'worcestershire sauce',
#  u'monterey jack',
#  u'fresh basil',
#  u'bay leaves',
#  u'crushed red pepper',
#  u'mussels',
#  u'olive oil',
#  u'basil',
#  u'garlic cloves',
#  u'black pepper',
#  u'dry white wine',
#  u'salt',
#  u'tomatoes',
#  u'finely chopped onion',
#  u'linguine',
#  u'flat leaf parsley',
#  u'sugar',
#  u'large eggs',
#  u'all-purpose flour',
#  u'baking soda',
#  u'buttermilk',
#  u'honey',
#  u'corn oil',
#  u'yellow corn meal',
#  u'unsalted butter',
#  u'salt',
#  u'lemon',
#  u'pesto',
#  u'salmon fillets',
#  u'white wine',
#  u'bread crumbs',
#  u'unsalted butter',
#  u'onion powder',
#  u'curry',
#  u'low sodium beef broth',
#  u'pickapeppa sauce',
#  u'curry powder',
#  u'bay leaves',
#  u'garlic',
#  u'cayenne pepper',
#  u'cold water',
#  u'pepper',
#  u'large eggs',
#  u'extra-virgin olive oil',
#  u'yellow onion',
#  u'allspice',
#  u'white vinegar',
#  u'kosher salt',
#  u'fresh thyme',
#  u'worcestershire sauce',
#  u'all-purpose flour',
#  u'ground beef',
#  u'melted butter',
#  u'matcha green tea powder',
#  u'white sugar',
#  u'milk',
#  u'all-purpose flour',
#  u'eggs',
#  u'salt',
#  u'baking powder',
#  u'chopped walnuts',
#  u'coarse salt',
#  u'fenugreek',
#  u'urad dal',
#  u'potatoes',
#  u'white rice',
#  u'vegetable oil',
#  u'pizza crust',
#  u'plum tomatoes',
#  u'pesto',
#  u'part-skim mozzarella cheese',
#  u'cooking spray',
#  u'salt',
#  u'black pepper',
#  u'yukon gold potatoes',
#  u'low-fat sour cream',
#  u'leeks',
#  u'olive oil',
#  u'1% low-fat milk',
#  u'sugar',
#  u'chicken thighs',
#  u'cooking oil',
#  u'fish sauce',
#  u'garlic',
#  u'black pepper',
#  u'lemongrass',
#  u'large garlic cloves',
#  u'rice',
#  u'unsweetened coconut milk',
#  u'fresh ginger',
#  u'peanut sauce',
#  u'spareribs',
#  u'sesame oil',
#  u'tamari soy sauce',
#  u'golden brown sugar',
#  u'dry sherry',
#  u'boiling water',
#  u'chicken legs',
#  u'chile pepper',
#  u'ghee',
#  u'tomato paste',
#  u'fresh ginger root',
#  u'garlic',
#  u'chopped cilantro fresh',
#  u'water',
#  u'vegetable oil',
#  u'onions',
#  u'tomatoes',
#  u'garam masala',
#  u'cumin seed',
#  u'ground turmeric',
#  u'stock',
#  u'curry powder',
#  u'cracked black pepper',
#  u'minced beef',
#  u'onions',
#  u'plain flour',
#  u'bread crumbs',
#  u'butter',
#  u'garlic',
#  u'celery',
#  u'cold water',
#  u'tumeric',
#  u'dried thyme',
#  u'ginger',
#  u'oil',
#  u'tomatoes',
#  u'water',
#  u'paprika',
#  u'salt',
#  u'chillies',
#  u'crushed tomatoes',
#  u'garlic',
#  u'fresh rosemary',
#  u'ground black pepper',
#  u'onions',
#  u'olive oil',
#  u'boneless pork loin',
#  u'kosher salt',
#  u'pappardelle',
#  u'extra firm tofu',
#  u'coconut milk',
#  u'fresh basil',
#  u'red curry paste',
#  u'eggplant',
#  u'red bell pepper',
#  u'vegetable oil',
#  u'onions',
#  u'jasmine rice',
#  u'garlic',
#  u'scallions',
#  u'sugar',
#  u'shiitake',
#  u'Gochujang base',
#  u'beansprouts',
#  u'top round steak',
#  u'sesame seeds',
#  u'rice vinegar',
#  u'carrots',
#  u'soy sauce',
#  u'sesame oil',
#  u'Taiwanese bok choy',
#  u'vanilla',
#  u'milk',
#  u'large egg yolks',
#  u'sugar',
#  u'corn starch',
#  u'orange juice concentrate',
#  u'pumpkin pur\xe9e',
#  u'marshmallow creme',
#  u'toasted pecans',
#  u'maple syrup',
#  u'ground cinnamon',
#  u'gingersnap',
#  u'ground nutmeg',
#  u'cream cheese',
#  u'black pepper',
#  u'white sugar',
#  u'white vinegar',
#  u'salt',
#  u'bacon',
#  u'brown sugar',
#  u'green beans',
#  u'large eggs',
#  u'serrano ham',
#  u'manchego cheese',
#  u'butter',
#  u'dijon mustard',
#  u'sourdough',
#  u'membrillo',
#  u'burger buns',
#  u'fresh cilantro',
#  u'chili powder',
#  u'garlic cloves',
#  u'panko breadcrumbs',
#  u'chickpea flour',
#  u'pepper',
#  u'Sriracha',
#  u'chickpeas',
#  u'carrots',
#  u'ground flaxseed',
#  u'soy sauce',
#  u'olive oil',
#  u'salt',
#  u'lemon juice',
#  u'greens',
#  u'spinach',
#  u'curry powder',
#  u'tahini',
#  u'scallions',
#  u'onions',
#  u'ground cumin',
#  u'ground cloves',
#  u'whole nutmegs',
#  u'ground ginger',
#  u'ground coriander',
#  u'ground cinnamon',
#  u'ground cardamom',
#  u'ground black pepper',
#  u'ground cumin',
#  u'tomatoes',
#  u'red pepper',
#  u'olive oil',
#  u'Italian bread',
#  u'balsamic vinegar',
#  u'onions',
#  u'fresh basil',
#  u'garlic',
#  u'sausage casings',
#  u'ground black pepper',
#  u'garlic',
#  u'honey',
#  u'grated parmesan cheese',
#  u'shredded mozzarella cheese',
#  u'kosher salt',
#  u'roasted red peppers',
#  u'penne pasta',
#  u'olive oil',
#  u'crushed red pepper flakes',
#  u'tumeric',
#  u'olive oil',
#  u'lemon',
#  u'saffron',
#  u'tomato paste',
#  u'pepper',
#  u'flour',
#  u'chickpeas',
#  u'chicken stock',
#  u'warm water',
#  u'fresh ginger',
#  u'salt',
#  u'tomatoes',
#  u'fresh cilantro',
#  u'shallots',
#  u'fresh parsley',
#  u'ground pepper',
#  u'paprika',
#  u'ground cardamom',
#  u'chopped cilantro fresh',
#  u'preserved lemon',
#  u'harissa',
#  u'salt',
#  u'couscous',
#  u'tomato paste',
#  u'cayenne',
#  u'garlic',
#  u'fat skimmed chicken broth',
#  u'ground turmeric',
#  u'pitted kalamata olives',
#  u'diced tomatoes',
#  u'fat',
#  u'onions',
#  u'sweetened condensed milk',
#  u'ice',
#  u'espresso',
#  u'top round steak',
#  u'vegetable oil',
#  u'shiitake',
#  u'soy sauce',
#  u'fresh asparagus',
#  u'green onions',
#  u'avocado',
#  u'chopped cilantro fresh',
#  u'jalapeno chilies',
#  u'finely chopped onion',
#  u'plum tomatoes',
#  u'green chilies',
#  u'pecans',
#  u'golden brown sugar',
#  u'crumbled blue cheese',
#  u'garlic cloves',
#  u'chuck',
#  u'hamburger buns',
#  u'hot pepper sauce',
#  u'creole seasoning',
#  u'onions',
#  u'mayonaise',
#  u'ground black pepper',
#  u'salt',
#  u'okra pods',
#  u'andouille sausage',
#  u'olive oil',
#  u'watercress',
#  u'fresh lemon juice',
#  u'sugar',
#  u'vanilla',
#  u'eggs',
#  u'self rising flour',
#  u'confectioners sugar',
#  u'milk',
#  u'softened butter',
#  u'food colouring',
#  u'butter',
#  u'Madeira',
#  u'foie gras',
#  u'demi-glace',
#  u'sherry vinegar',
#  u'whipping cream',
#  u'white bread',
#  u'Fuyu persimmons',
#  u'salt',
#  u'egg bread',
#  u'watercress',
#  u'fenugreek leaves',
#  u'olive oil',
#  u'garlic',
#  u'black mustard seeds',
#  u'ground cumin',
#  u'amchur',
#  u'lime wedges',
#  u'scallions',
#  u'coriander',
#  u'sugar',
#  u'fingerling potatoes',
#  u'green chilies',
#  u'chopped cilantro',
#  u'tumeric',
#  u'fresh ginger root',
#  u'salt',
#  u'ramps',
#  u'black peppercorns',
#  u'cinnamon sticks',
#  u'cardamom pods',
#  u'cumin seed',
#  u'coriander seeds',
#  u'spinach',
#  u'asiago',
#  u'whole wheat pasta',
#  u'olive oil',
#  u'sweet onion',
#  u'garlic',
#  u'grape tomatoes',
#  u'mushrooms',
#  u'chestnuts',
#  u'granulated sugar',
#  u'whole milk ricotta cheese',
#  u'coffee ice cream',
#  u'large eggs',
#  u'mascarpone',
#  u'rum',
#  u'powdered sugar',
#  u'semisweet chocolate',
#  u'chestnut flour',
#  u'baby spinach leaves',
#  u'naan',
#  u'unsalted butter',
#  u'chopped garlic',
#  u'water',
#  u'large shrimp',
#  u'tomatoes',
#  u'salt',
#  u'water',
#  u'barley',
#  u'cooked ham',
#  u'red bell pepper',
#  u'seasoning',
#  u'potatoes',
#  u'olive oil',
#  u'onions',
#  u'eggs',
#  u'bacon',
#  u'salt',
#  u'starchy potatoes',
#  u'grated nutmeg',
#  u'flour',
#  u'ground black pepper',
#  u'all-purpose flour',
#  u'milk',
#  u'buttermilk',
#  u'sirloin tip roast',
#  u'coarse salt',
#  u'steak',
#  u'vegetable oil',
#  u'cayenne pepper',
#  u'granulated sugar',
#  u'all-purpose flour',
#  u'vegetable shortening',
#  u'baking powder',
#  u'milk',
#  u'salt',
#  u'ground pork',
#  u'finely chopped fresh parsley',
#  u'onions',
#  u'salt',
#  u'vinegar',
#  u'caul fat',
#  u'ground cinnamon',
#  u'whole milk',
#  u'golden brown sugar',
#  u'heavy whipping cream',
#  u'kahl\xfaa',
#  u'corn starch',
#  u'instant espresso powder',
#  u'boneless chicken skinless thigh',
#  u'lime',
#  u'epazote',
#  u'bay leaf',
#  u'lime juice',
#  u'radishes',
#  u'salt',
#  u'oregano',
#  u'white onion',
#  u'hominy',
#  u'garlic',
#  u'chopped cilantro',
#  u'avocado',
#  u'fresh cilantro',
#  u'tomatillos',
#  u'pepitas',
#  u'canola oil',
#  u'catfish fillets',
#  u'ground black pepper',
#  u'salt',
#  u'dried thyme',
#  u'ground red pepper',
#  u'peanut oil',
#  u'yellow corn meal',
#  u'large eggs',
#  u'all-purpose flour',
#  u'garlic powder',
#  u'buttermilk',
#  u'olive oil',
#  u'sea salt',
#  u'coconut milk',
#  u'water',
#  u'garam masala',
#  u'ground coriander',
#  u'basmati rice',
#  u'cauliflower',
#  u'fresh ginger',
#  u'green chilies',
#  u'onions',
#  u'fresh cilantro',
#  u'potatoes',
#  u'scallions',
#  u'cumin',
#  u'olive oil',
#  u'olives',
#  u'salt',
#  u'blood orange',
#  u'freshly ground pepper',
#  u'fennel bulb',
#  u'balsamic vinegar',
#  u'low salt chicken broth',
#  u'dijon mustard',
#  u'corn starch',
#  u'dried basil',
#  u'garlic cloves',
#  u'white wine vinegar',
#  u'tomato sauce',
#  u'shredded carrots',
#  u'spinach',
#  u'part-skim mozzarella cheese',
#  u'italian seasoning',
#  u'english muffins, split and toasted',
#  u'chopped onion',
#  u'vegetable oil cooking spray',
#  u'chopped green bell pepper',
#  u'prawns',
#  u'rice flour',
#  u'seasoning salt',
#  u'salt',
#  u'vegetable oil',
#  u'club soda',
#  ...]

# %%
print('Feature set shape: {}'.format(all_inputs.shape))
print('Class set shape: {}'.format(all_classes.shape))
# Out:
# Feature set shape: (39774, 3010)
# Class set shape: (39774,)

# %%
len(le.classes_)
# Out:
# 20

# %%
set(train_Y)
# Out:
# {u'brazilian',
#  u'british',
#  u'cajun_creole',
#  u'chinese',
#  u'filipino',
#  u'french',
#  u'greek',
#  u'indian',
#  u'irish',
#  u'italian',
#  u'jamaican',
#  u'japanese',
#  u'korean',
#  u'mexican',
#  u'moroccan',
#  u'russian',
#  u'southern_us',
#  u'spanish',
#  u'thai',
#  u'vietnamese'}

# %%
set(train_X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ffab7c690cb8> in <module>()
# ----> 1 head(set(train_X))
#
# NameError: name 'head' is not defined

# %% [markdown]
# #### Create main test and training data sets

# %%
from sklearn.cross_validation import train_test_split

(training_inputs,
 testing_inputs,
 training_classes,
 testing_classes) = train_test_split(all_inputs, all_classes, train_size=0.9)

# %%
print "training_inputs shape:\t{}".format(training_inputs.shape)
print "testing_inputs shape:\t{}".format(testing_inputs.shape)
print "training_classes shape:\t{}".format(training_classes.shape)
print "testing_classes shape:\t{}".format(testing_classes.shape)
# Out:
# training_inputs shape:	(35796, 3010)
# testing_inputs shape:	(3978, 3010)
# training_classes shape:	(35796,)
# testing_classes shape:	(3978,)

# %% [markdown]
# #### Create LSA matrix aka TruncatedSVD
# LSA is a dimensional reduction decomposition that works well with sparse feature vectors such as out vector of recipe
# ingredient vectors.

# %%
from sklearn.decomposition import TruncatedSVD

# %time svd_dict = { n:TruncatedSVD(n_components=n).fit(training_inputs) for n in [50,100,200,300,500,750,1000] }

for n in svd_dict:
    print svd_dict[n]
# Out:
# CPU times: user 10min 34s, sys: 5.02 s, total: 10min 39s
# Wall time: 10min 40s
# TruncatedSVD(algorithm='randomized', n_components=100, n_iter=5,
#        random_state=None, tol=0.0)
# TruncatedSVD(algorithm='randomized', n_components=200, n_iter=5,
#        random_state=None, tol=0.0)
# TruncatedSVD(algorithm='randomized', n_components=300, n_iter=5,
#        random_state=None, tol=0.0)
# TruncatedSVD(algorithm='randomized', n_components=750, n_iter=5,
#        random_state=None, tol=0.0)
# TruncatedSVD(algorithm='randomized', n_components=1000, n_iter=5,
#        random_state=None, tol=0.0)
# TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0)
# TruncatedSVD(algorithm='randomized', n_components=500, n_iter=5,
#        random_state=None, tol=0.0)

# %% [markdown]
# #### Save our LSA matrix results

# %%
import pickle

with open('recipe_SVD', 'wb') as p_file:
    pickle.dump(svd_dict, p_file)

# %%
import pickle

with open('recipe_SVD', 'rb') as p_file:
    svd_dict = pickle.load(p_file)
svd_dict
# Out:
# {50: TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#         random_state=None, tol=0.0),
#  100: TruncatedSVD(algorithm='randomized', n_components=100, n_iter=5,
#         random_state=None, tol=0.0),
#  200: TruncatedSVD(algorithm='randomized', n_components=200, n_iter=5,
#         random_state=None, tol=0.0),
#  300: TruncatedSVD(algorithm='randomized', n_components=300, n_iter=5,
#         random_state=None, tol=0.0),
#  500: TruncatedSVD(algorithm='randomized', n_components=500, n_iter=5,
#         random_state=None, tol=0.0),
#  750: TruncatedSVD(algorithm='randomized', n_components=750, n_iter=5,
#         random_state=None, tol=0.0),
#  1000: TruncatedSVD(algorithm='randomized', n_components=1000, n_iter=5,
#         random_state=None, tol=0.0)}

# %%
for n in svd_dict:
    print svd_dict[n].explained_variance_ratio_
# Out:
# [ 0.0537537   0.0405683   0.03970967  0.03352375  0.03071084  0.02506659
#   0.02292305  0.02109944  0.0184094   0.01569385  0.01445968  0.01378796
#   0.013291    0.01298644  0.01160924  0.01089266  0.01050467  0.01015769
#   0.00997771  0.00939528  0.00884424  0.00870331  0.00848269  0.0083548
#   0.00820064  0.00783893  0.00752834  0.00732935  0.00717604  0.00694989
#   0.00683041  0.0063715   0.0062635   0.00593224  0.005526    0.00543062
#   0.0052506   0.00518298  0.00507236  0.00491248  0.00490934  0.00473531
#   0.00469428  0.00448906  0.00444085  0.00432418  0.00427335  0.00416345
#   0.00410675  0.00392819  0.0038984   0.00384065  0.00372571  0.00366821
#   0.00352074  0.00351732  0.00346289  0.0034213   0.00332937  0.00323823
#   0.00322057  0.00316793  0.00315298  0.00312582  0.00310401  0.00305448
#   0.00293252  0.00289417  0.00284892  0.00281784  0.00277622  0.00271629
#   0.00269388  0.00265645  0.00262966  0.00258673  0.00254467  0.00252799
#   0.00246877  0.00244778  0.00241189  0.00237964  0.00234494  0.00232394
#   0.00229291  0.00224415  0.00221515  0.0021952   0.00215511  0.00213977
#   0.00205685  0.00202282  0.00200659  0.00197534  0.00193572  0.00189258
#   0.0018754   0.00183801  0.00182181  0.00179043]
# [ 0.0537537   0.0405683   0.03970967  0.03352375  0.03071084  0.02506659
#   0.02292305  0.02109944  0.0184094   0.01569385  0.01445968  0.01378796
#   0.013291    0.01298644  0.01160924  0.01089266  0.01050467  0.01015769
#   0.00997771  0.00939528  0.00884424  0.00870331  0.00848269  0.0083548
#    1.23961792e-05   1.19065137e-05   1.07988812e-05   9.50676333e-06
#    8.77992868e-06   8.21265320e-06   7.69617389e-06   7.02611395e-06
#    5.97956902e-06   5.72915638e-06   4.39489976e-06   3.68676298e-06]

# %%
print "n_components\tpercentage of variance explained"
for n in sorted(svd_dict.keys()):
    print "{}\t{}".format(n, svd_dict[n].explained_variance_ratio_.sum())
# Out:
# n_components	percentage of variance explained
# 50	0.598163568865
# 100	0.732675330504
# 200	0.848080635678
# 300	0.899037472944
# 500	0.944672248812
# 750	0.969024944047
# 1000	0.980993477312

# %% [markdown]
# #### generate SVD training inputs

# %%
svd_training_inputs = {}

for n in sorted(svd_dict.keys()):
    svd_training_inputs[n] = svd_dict[n].transform(training_inputs)
    print svd_training_inputs[n].shape
    print svd_training_inputs[n][1,:].shape
# Out:
# (35796, 50)
# (50,)
# (35796, 100)
# (100,)
# (35796, 200)
# (200,)
# (35796, 300)
# (300,)
# (35796, 500)
# (500,)
# (35796, 750)
# (750,)
# (35796, 1000)
# (1000,)

# %%
svd_testing_inputs = {}

for n in sorted(svd_dict.keys()):
    svd_testing_inputs[n] = svd_dict[n].transform(testing_inputs)
    print svd_testing_inputs[n].shape
    print svd_testing_inputs[n][1,:].shape
# Out:
# (3978, 50)
# (50,)
# (3978, 100)
# (100,)
# (3978, 200)
# (200,)
# (3978, 300)
# (300,)
# (3978, 500)
# (500,)
# (3978, 750)
# (750,)
# (3978, 1000)
# (1000,)

# %% [markdown]
# #### save the test and training svd matrixes

# %%
import pickle

with open('recipe_SVD_training_inputs', 'wb') as p_file:
    pickle.dump(svd_training_inputs, p_file)
with open('recipe_SVD_testing_inputs', 'wb') as p_file:
    pickle.dump(svd_testing_inputs, p_file)

# %%
?

# %%
import pickle

with open('recipe_SVD_training_inputs', 'rb') as p_file:
    svd_training_inputs = pickle.load(p_file)
with open('recipe_SVD_testing_inputs', 'rb') as p_file:
    svd_testing_inputs = pickle.load(p_file)

# %%
# sanity check for the sizes of out matrices
for n in sorted(svd_dict.keys()):
    svd_training_inputs[n] = svd_dict[n].transform(training_inputs)
    print svd_training_inputs[n].shape
    print svd_training_inputs[n][1,:].shape
print training_classes.shape
for n in sorted(svd_dict.keys()):
    svd_testing_inputs[n] = svd_dict[n].transform(testing_inputs)
    print svd_testing_inputs[n].shape
    print svd_testing_inputs[n][1,:].shape
print testing_classes.shape
# Out:
# (35796, 50)
# (50,)
# (35796, 100)
# (100,)
# (35796, 200)
# (200,)
# (35796, 300)
# (300,)
# (35796, 500)
# (500,)
# (35796, 750)
# (750,)
# (35796, 1000)
# (1000,)
# (35796,)
# (3978, 50)
# (50,)
# (3978, 100)
# (100,)
# (3978, 200)
# (200,)
# (3978, 300)
# (300,)
# (3978, 500)
# (500,)
# (3978, 750)
# (750,)
# (3978, 1000)
# (1000,)
# (3978,)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.cross_validation import train_test_split
import matplotlib.pyplot as plt
import seaborn as sb

decision_tree_classifier = DecisionTreeClassifier()

decision_tree_classifier.fit(svd_training_inputs[100], training_classes)
classifier_accuracy = decision_tree_classifier.score(svd_testing_inputs[100], testing_classes)

# %%
classifier_accuracy
# Out:
# 0.42533936651583709

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.cross_validation import train_test_split
import matplotlib.pyplot as plt
import seaborn as sb

model_accuracies = []

for repetition in range(10):
    (acc_training_inputs,
     acc_testing_inputs,
     acc_training_classes,
     acc_testing_classes) = train_test_split(svd_training_inputs, training_classes, train_size=0.75)
    
    decision_tree_classifier = DecisionTreeClassifier()
    decision_tree_classifier.fit(acc_training_inputs, training_classes)
    classifier_accuracy = decision_tree_classifier.score(acc_testing_inputs, testing_classes)
    model_accuracies.append(classifier_accuracy)
    
sb.distplot(model_accuracies)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-85a528c2cc4a> in <module>()
#      10      acc_testing_inputs,
#      11      acc_training_classes,
# ---> 12      acc_testing_classes) = train_test_split(svd_training_inputs, training_classes, train_size=0.75)
#      13
#      14     decision_tree_classifier = DecisionTreeClassifier()
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/sklearn/cross_validation.pyc in train_test_split(*arrays, **options)
#    1806     if test_size is None and train_size is None:
#    1807         test_size = 0.25
# -> 1808     arrays = indexable(*arrays)
#    1809     n_samples = _num_samples(arrays[0])
#    1810     cv = ShuffleSplit(n_samples, test_size=test_size,
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/sklearn/utils/validation.pyc in indexable(*iterables)
#     197         else:
#     198             result.append(np.array(X))
# --> 199     check_consistent_length(*result)
#     200     return result
#     201
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_consistent_length(*arrays)
#     172     if len(uniques) > 1:
#     173         raise ValueError("Found arrays with inconsistent numbers of samples: "
# --> 174                          "%s" % str(uniques))
#     175
#     176
#
# ValueError: Found arrays with inconsistent numbers of samples: [    7 35796]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.cross_validation import train_test_split
import matplotlib.pyplot as plt
import seaborn as sb

model_accuracies = []

for repetition in range(10):
    (training_inputs,
     testing_inputs,
     training_classes,
     testing_classes) = train_test_split(all_inputs, all_classes, train_size=0.75)
    
    decision_tree_classifier = DecisionTreeClassifier()
    decision_tree_classifier.fit(training_inputs, training_classes)
    classifier_accuracy = decision_tree_classifier.score(testing_inputs, testing_classes)
    model_accuracies.append(classifier_accuracy)
    
sb.distplot(model_accuracies)

# %%
from sklearn.tree import DecisionTreeClassifier

from sklearn.cross_validation import train_test_split

(training_inputs,
 testing_inputs,
 training_classes,
 testing_classes) = train_test_split(all_inputs, all_classes, train_size=0.9)

decision_tree_classifier = DecisionTreeClassifier()

# %time decision_tree_classifier.fit(training_inputs, training_classes)

for input_features, prediction, actual in zip(testing_inputs[:50],
                                              decision_tree_classifier.predict(testing_inputs[:50]),
                                              testing_classes[:50]):
    print('{}\t-->\t{}\t(Actual: {})'.format(input_features, prediction, actual))
# Out:
# CPU times: user 42.5 s, sys: 116 ms, total: 42.6 s
# Wall time: 42.6 s
# [0 0 0 ..., 0 0 0]	-->	13	(Actual: 9)
# [0 0 0 ..., 0 0 0]	-->	9	(Actual: 9)
# [0 0 0 ..., 0 0 0]	-->	16	(Actual: 2)
# [0 0 0 ..., 0 0 0]	-->	15	(Actual: 6)
# [0 0 0 ..., 0 0 0]	-->	3	(Actual: 3)
# [0 0 0 ..., 0 0 0]	-->	16	(Actual: 6)
# [0 0 0 ..., 0 0 0]	-->	17	(Actual: 6)
# [0 0 0 ..., 0 0 0]	-->	13	(Actual: 13)
# [0 0 0 ..., 0 0 0]	-->	16	(Actual: 16)
# [0 0 0 ..., 0 0 0]	-->	9	(Actual: 9)
# [0 0 0 ..., 0 0 0]	-->	10	(Actual: 10)
# [0 0 0 ..., 0 0 0]	-->	12	(Actual: 3)
# [0 0 0 ..., 0 0 0]	-->	9	(Actual: 16)
# [0 0 0 ..., 0 0 0]	-->	13	(Actual: 13)
# [0 0 0 ..., 0 0 0]	-->	11	(Actual: 11)
# [0 0 0 ..., 0 0 0]	-->	16	(Actual: 16)
# [0 0 0 ..., 0 0 0]	-->	14	(Actual: 6)
# [0 0 0 ..., 0 0 0]	-->	0	(Actual: 0)
# [0 0 0 ..., 0 0 0]	-->	7	(Actual: 7)
# [0 0 0 ..., 0 0 0]	-->	9	(Actual: 9)
# [0 0 0 ..., 0 0 0]	-->	18	(Actual: 18)
# [0 0 0 ..., 0 0 0]	-->	13	(Actual: 15)
# [0 0 0 ..., 0 0 0]	-->	9	(Actual: 9)
# [0 0 0 ..., 0 0 0]	-->	1	(Actual: 3)
# [0 0 0 ..., 0 0 0]	-->	13	(Actual: 13)
# [0 0 0 ..., 0 0 0]	-->	16	(Actual: 5)
# [0 0 0 ..., 0 0 0]	-->	9	(Actual: 9)
# [0 0 0 ..., 0 0 0]	-->	17	(Actual: 15)
# [0 0 0 ..., 0 0 0]	-->	9	(Actual: 9)
# [0 0 0 ..., 0 0 0]	-->	9	(Actual: 9)
# [0 0 0 ..., 0 0 0]	-->	3	(Actual: 4)
# [0 0 0 ..., 0 0 0]	-->	7	(Actual: 10)
# [0 0 0 ..., 0 0 0]	-->	9	(Actual: 9)
# [0 0 0 ..., 0 0 0]	-->	13	(Actual: 13)
# [0 0 0 ..., 0 0 0]	-->	18	(Actual: 4)
# [0 0 0 ..., 0 0 0]	-->	1	(Actual: 3)
# [0 0 0 ..., 0 0 0]	-->	13	(Actual: 13)
# [0 0 0 ..., 0 0 0]	-->	5	(Actual: 9)
# [0 0 0 ..., 0 1 0]	-->	13	(Actual: 13)
# [0 0 0 ..., 0 0 0]	-->	1	(Actual: 9)
# [0 0 0 ..., 0 0 0]	-->	2	(Actual: 6)
# [0 0 0 ..., 0 0 0]	-->	9	(Actual: 5)
# [0 0 0 ..., 0 0 0]	-->	7	(Actual: 7)
# [0 0 0 ..., 0 0 0]	-->	5	(Actual: 2)
# [0 0 0 ..., 0 0 0]	-->	18	(Actual: 18)
# [0 0 0 ..., 0 0 0]	-->	9	(Actual: 9)
# [0 0 0 ..., 0 0 0]	-->	3	(Actual: 3)
# [0 0 0 ..., 0 0 0]	-->	9	(Actual: 9)
# [0 0 0 ..., 0 0 0]	-->	3	(Actual: 3)
# [0 0 0 ..., 0 0 0]	-->	13	(Actual: 17)

# %%
for input_features, prediction, actual in zip(testing_inputs[:50],
                                              decision_tree_classifier.predict(testing_inputs[:50]),
                                              testing_classes[:50]):
    print 'Prediction: {}\t(Actual: {})'.format(le.inverse_transform(prediction), le.inverse_transform(actual))
# Out:
# Prediction: vietnamese	(Actual: vietnamese)
# Prediction: mexican	(Actual: british)
# Prediction: vietnamese	(Actual: chinese)
# Prediction: italian	(Actual: italian)
# Prediction: mexican	(Actual: mexican)
# Prediction: japanese	(Actual: japanese)
# Prediction: mexican	(Actual: mexican)
# Prediction: italian	(Actual: italian)
# Prediction: mexican	(Actual: mexican)
# Prediction: southern_us	(Actual: southern_us)
# Prediction: jamaican	(Actual: jamaican)
# Prediction: mexican	(Actual: mexican)
# Prediction: moroccan	(Actual: moroccan)
# Prediction: italian	(Actual: italian)
# Prediction: korean	(Actual: korean)
# Prediction: mexican	(Actual: mexican)
# Prediction: chinese	(Actual: chinese)
# Prediction: mexican	(Actual: mexican)
# Prediction: southern_us	(Actual: cajun_creole)
# Prediction: italian	(Actual: italian)
# Prediction: chinese	(Actual: chinese)
# Prediction: chinese	(Actual: chinese)
# Prediction: italian	(Actual: italian)
# Prediction: moroccan	(Actual: moroccan)
# Prediction: mexican	(Actual: mexican)
# Prediction: japanese	(Actual: japanese)
# Prediction: chinese	(Actual: southern_us)
# Prediction: southern_us	(Actual: british)
# Prediction: italian	(Actual: italian)
# Prediction: indian	(Actual: cajun_creole)
# Prediction: chinese	(Actual: chinese)
# Prediction: vietnamese	(Actual: vietnamese)
# Prediction: mexican	(Actual: mexican)
# Prediction: italian	(Actual: italian)
# Prediction: italian	(Actual: spanish)
# Prediction: southern_us	(Actual: southern_us)
# Prediction: italian	(Actual: italian)
# Prediction: chinese	(Actual: chinese)
# Prediction: indian	(Actual: indian)
# Prediction: mexican	(Actual: moroccan)
# Prediction: french	(Actual: southern_us)
# Prediction: cajun_creole	(Actual: southern_us)
# Prediction: italian	(Actual: italian)
# Prediction: chinese	(Actual: chinese)
# Prediction: mexican	(Actual: mexican)
# Prediction: greek	(Actual: greek)
# Prediction: mexican	(Actual: moroccan)
# Prediction: chinese	(Actual: italian)
# Prediction: chinese	(Actual: chinese)
# Prediction: spanish	(Actual: spanish)

# %%
from learning_curve_helpers import make_learning_curve, plot_learning_curve_from_learning_curve_data

# %time dt_lc_output = make_learning_curve(decision_tree_classifier, training_inputs, training_classes, cv=5)
# Out:
# CPU times: user 496 ms, sys: 928 ms, total: 1.42 s
# Wall time: 4min 55s

# %%
dt_lc_plot = plot_learning_curve_from_learning_curve_data('Decision Tree No Prune Learning Curve', *dt_lc_output)
# Out:
# train test sizes: [ 2863  5726  8589 11452 14315 17178 20041 22904 25767 28631]
# train scores means: [ 1.          0.99986029  0.99988357  0.99991268  0.99988823  0.99981372
#   0.99977047  0.99973804  0.99968953  0.99967867]
# train scores std: [  0.00000000e+00   6.98567936e-05   7.36355259e-05   5.52266444e-05
#    5.58854349e-05   6.78886005e-05   3.99181678e-05   4.78276770e-05
#    4.90903506e-05   4.63361362e-05]
# test scores mean: [ 0.52251732  0.55721374  0.57146186  0.59149305  0.60465048  0.61202415
#   0.61931664  0.62467927  0.62736162  0.62931669]
# test scores std: [ 0.0038466   0.00523557  0.0042319   0.00475804  0.00636952  0.00188113
#   0.00890342  0.00520714  0.00234606  0.00446112]

# %%
from sklearn import tree
from sklearn.externals.six import StringIO
import pydot
dot_data = StringIO()
tree.export_graphviz(decision_tree_classifier, out_file=dot_data)
graph = pydot.graph_from_dot_data(dot_data.getvalue())
graph.write_pdf('cook_unpruned.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-c37d8a4ad9e8> in <module>()
#       4 dot_data = StringIO()
#       5 tree.export_graphviz(decision_tree_classifier, out_file=dot_data)
# ----> 6 graph = pydot.graph_from_dot_data(dot_data.getvalue())
#       7 graph.write_pdf('cook_unpruned.pdf')
#       8
#
# /Users/timothylaurent/anaconda/lib/python2.7/site-packages/pydot.pyc in graph_from_dot_data(data)
#     197         return s
#     198
# --> 199     if needs_quotes(s):
#     200         replace = {'"'  : r'\"',
#     201                    "\n" : r'\n',
#
# NameError: global name 'dot_parser' is not defined

# %%
from sklearn.grid_search import RandomizedSearchCV, GridSearchCV
from sklearn.cross_validation import StratifiedKFold
from scipy import stats

param_dist = {"max_depth": [10, 20, 50, None],
              "max_features": [1000, 1500, 2000, 2500, 3000],
              "criterion": ["gini", "entropy"]}

decision_tree_classifier = DecisionTreeClassifier()

cv = StratifiedKFold(training_classes, n_folds=3)

# rs = RandomizedSearchCV(decision_tree_classifier, param_distributions=param_dist, n_jobs=-1)

# %time rs.fit(training_inputs, training_classes)


# print('Best score: {}'.format(rs.best_score_))
# print('Best parameters: {}'.format(rs.best_params_))

gs = GridSearchCV(decision_tree_classifier, param_grid=param_dist, n_jobs=-1)

# %time gs.fit(training_inputs, training_classes) 
print('Best score: {}'.format(gs.best_score_))
print('Best parameters: {}'.format(gs.best_params_))
# Out:
# CPU times: user 33.9 s, sys: 3.24 s, total: 37.1 s
# Wall time: 10min 2s
# Best score: 0.626606324729
# Best parameters: {'max_features': 2000, 'criterion': 'gini', 'max_depth': None}

# %%
best_decision_tree = gs.best_estimator_

# %%
from sklearn.grid_search import RandomizedSearchCV, GridSearchCV
from sklearn.cross_validation import StratifiedKFold
from scipy import stats
import numpy as np

param_dist = {"max_features": [1600,1700,1800,1900,2100,2200,2300,2400],
              "criterion": ["gini", "entropy"]}
print training_inputs.shape
print param_dist

decision_tree_classifier = DecisionTreeClassifier()

cv = StratifiedKFold(training_classes, n_folds=3)

# rs = RandomizedSearchCV(decision_tree_classifier, param_distributions=param_dist, n_jobs=-1)

# %time rs.fit(training_inputs, training_classes)


# print('Best score: {}'.format(rs.best_score_))
# print('Best parameters: {}'.format(rs.best_params_))

gs = GridSearchCV(decision_tree_classifier, param_grid=param_dist, n_jobs=-1)

# %time gs.fit(training_inputs, training_classes) 
print('Best score: {}'.format(gs.best_score_))
print('Best parameters: {}'.format(gs.best_params_))
# Out:
# (35796, 3010)
# {'max_features': [1600, 1700, 1800, 1900, 2100, 2200, 2300, 2400], 'criterion': ['gini', 'entropy']}
# CPU times: user 36 s, sys: 2.92 s, total: 39 s
# Wall time: 5min 19s
# Best score: 0.625488881439
# Best parameters: {'max_features': 2100, 'criterion': 'gini'}

# %%
from learning_curve_helpers import make_learning_curve, plot_learning_curve_from_learning_curve_data

decision_tree_classifier = best_decision_tree

# %time dt_lc_output = make_learning_curve(decision_tree_classifier, training_inputs, training_classes, cv=5)
# Out:
# CPU times: user 581 ms, sys: 1.53 s, total: 2.11 s
# Wall time: 4min 15s

# %%
dt_lc_plot = plot_learning_curve_from_learning_curve_data('Decision Tree Learning Curve', *dt_lc_output)
# Out:
# train test sizes: [ 2862  5725  8588 11451 14314 17177 20040 22903 25766 28629]
# train scores means: [ 1.          1.          0.99995342  0.99996507  0.99993014  0.99989521
#   0.99984032  0.99980789  0.99979042  0.99977645]
# train scores std: [  0.00000000e+00   0.00000000e+00   9.31532371e-05   6.98628941e-05
#    4.41844021e-05   6.78925528e-05   1.99600798e-05   3.49299218e-05
#    3.95794420e-05   3.56213596e-05]
# test scores mean: [ 0.52334942  0.55452714  0.57587355  0.5898421   0.60367002  0.6101251
#   0.61691612  0.62272468  0.63026545  0.62909577]
# test scores std: [ 0.01224081  0.00668864  0.00660165  0.00589161  0.00379414  0.00565053
#   0.00617993  0.00461356  0.00360581  0.00506166]

# %%
for input_features, prediction, actual in zip(testing_inputs[:50],
                                              decision_tree_classifier.predict(testing_inputs[:50]),
                                              testing_classes[:50]):
    print 'Prediction: {}\t(Actual: {})'.format(le.inverse_transform(prediction), le.inverse_transform(actual))
# Out:
# Prediction: vietnamese	(Actual: vietnamese)
# Prediction: french	(Actual: british)
# Prediction: vietnamese	(Actual: chinese)
# Prediction: italian	(Actual: italian)
# Prediction: mexican	(Actual: mexican)
# Prediction: japanese	(Actual: japanese)
# Prediction: mexican	(Actual: mexican)
# Prediction: italian	(Actual: italian)
# Prediction: mexican	(Actual: mexican)
# Prediction: southern_us	(Actual: southern_us)
# Prediction: jamaican	(Actual: jamaican)
# Prediction: mexican	(Actual: mexican)
# Prediction: moroccan	(Actual: moroccan)
# Prediction: italian	(Actual: italian)
# Prediction: korean	(Actual: korean)
# Prediction: mexican	(Actual: mexican)
# Prediction: chinese	(Actual: chinese)
# Prediction: mexican	(Actual: mexican)
# Prediction: southern_us	(Actual: cajun_creole)
# Prediction: italian	(Actual: italian)
# Prediction: chinese	(Actual: chinese)
# Prediction: japanese	(Actual: chinese)
# Prediction: italian	(Actual: italian)
# Prediction: moroccan	(Actual: moroccan)
# Prediction: mexican	(Actual: mexican)
# Prediction: chinese	(Actual: japanese)
# Prediction: southern_us	(Actual: southern_us)
# Prediction: southern_us	(Actual: british)
# Prediction: italian	(Actual: italian)
# Prediction: mexican	(Actual: cajun_creole)
# Prediction: chinese	(Actual: chinese)
# Prediction: vietnamese	(Actual: vietnamese)
# Prediction: mexican	(Actual: mexican)
# Prediction: french	(Actual: italian)
# Prediction: spanish	(Actual: spanish)
# Prediction: southern_us	(Actual: southern_us)
# Prediction: french	(Actual: italian)
# Prediction: chinese	(Actual: chinese)
# Prediction: indian	(Actual: indian)
# Prediction: mexican	(Actual: moroccan)
# Prediction: french	(Actual: southern_us)
# Prediction: spanish	(Actual: southern_us)
# Prediction: italian	(Actual: italian)
# Prediction: chinese	(Actual: chinese)
# Prediction: mexican	(Actual: mexican)
# Prediction: greek	(Actual: greek)
# Prediction: spanish	(Actual: moroccan)
# Prediction: french	(Actual: italian)
# Prediction: chinese	(Actual: chinese)
# Prediction: spanish	(Actual: spanish)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=500)
# %time pca_model = pca.fit(all_inputs)

# %time pca_inputs = pca_model.transform(all_inputs)
pca_inputs.shape
# Out:
# CPU times: user 3min 48s, sys: 4.5 s, total: 3min 52s
# Wall time: 51 s
# CPU times: user 8.78 s, sys: 501 ms, total: 9.28 s
# Wall time: 2.09 s
# (39774, 500)

# %%
from learning_curve_helpers import make_learning_curve, plot_learning_curve_from_learning_curve_data

decision_tree_classifier = DecisionTreeClassifier()

# %time dt_lc_output = make_learning_curve(decision_tree_classifier, pca_inputs, all_classes, cv=5)
# Out:
# CPU times: user 495 ms, sys: 374 ms, total: 869 ms
# Wall time: 4min 9s

# %%
dt_lc_output
# Out:
# (array([ 3181,  6362,  9543, 12724, 15906, 19087, 22268, 25449, 28630, 31812]),
#  array([[ 1.        ,  1.        ,  1.        ,  1.        ,  1.        ],
#         [ 1.        ,  0.99968563,  0.99968563,  0.99968563,  0.99968563],
#         [ 1.        ,  0.99979042,  0.99979042,  0.99979042,  0.99979042],
#         [ 1.        ,  0.99984282,  0.99984282,  0.99984282,  0.99984282],
#         [ 0.99993713,  0.99981139,  0.99987426,  0.99987426,  0.99987426],
#         [ 0.99989522,  0.99979043,  0.99989522,  0.99989522,  0.99989522],
#         [ 0.99982037,  0.99973056,  0.99982037,  0.99982037,  0.99982037],
#         [ 0.99972494,  0.99968565,  0.99968565,  0.99980353,  0.99980353],
#         [ 0.99972057,  0.99961579,  0.99968564,  0.9997555 ,  0.9997555 ],
#         [ 0.99974852,  0.99965422,  0.99971709,  0.99977996,  0.99968565]]),
#  array([[ 1.        ,  1.        ,  1.        ,  1.        ,  1.        


# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=10)
# %time pca_model_10 = pca.fit(all_inputs)

# %time pca_inputs_10 = pca_model.transform(all_inputs)
pca_inputs_10.shape
# Out:
# CPU times: user 3min 45s, sys: 3.59 s, total: 3min 49s
# Wall time: 48 s
# CPU times: user 33.3 s, sys: 727 ms, total: 34 s
# Wall time: 6.05 s
# (39774, 2000)

# %%
from sklearn.decomposition import PCA

# %time pca_dict = { n:PCA(n_components=n).fit(all_inputs) for n in [10,20,40,100,500,1000,2000] }

# %%
from sklearn.decomposition import SparsePCA

# %time SparsePCA(n_components=20, n_jobs=-1).fit(training_inputs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b32542c7ed51> in <module>()
#       1 from sklearn.decomposition import SparsePCA
#       2
# ----> 3 get_ipython().magic(u'time SparsePCA(n_components=20, n_jobs=-1).fit(training_inputs)')
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2334         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2335         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2336         return self.run_line_magic(magic_name, magic_arg_s)
#    2337
#    2338     #-------------------------------------------------------------------------
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2255                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2256             with self.builtin_trap:
# -> 2257                 result = fn(*args,**kwargs)
#    2258             return result
#    2259
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1161         if mode=='eval':
#    1162             st = clock2()
# -> 1163             out = eval(code, glob, local_ns)
#    1164             end = clock2()
#    1165         else:
#
# <timed eval> in <module>()
#
# NameError: name 'training_inputs' is not defined

# %%
from sklearn.decomposition import SparsePCA

# %time sparse_pca_dict = { n:SparsePCA(n_components=n, n_jobs=-1).fit(training_inputs) for n in [20,40,100,500,1000,2000,3000] }

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=1000)
# %time pca_model = pca.fit(all_inputs)

# %time pca_inputs = pca_model.transform(all_inputs)
pca_inputs.shape
# Out:
# CPU times: user 3min 52s, sys: 6.42 s, total: 3min 59s
# Wall time: 56.1 s
# CPU times: user 19.8 s, sys: 714 ms, total: 20.6 s
# Wall time: 4.37 s
# (39774, 1000)

# %%
from learning_curve_helpers import make_learning_curve, plot_learning_curve_from_learning_curve_data

decision_tree_classifier = DecisionTreeClassifier()

# %time dt_lc_output = make_learning_curve(decision_tree_classifier, pca_inputs, all_classes, cv=5)
# Out:
# CPU times: user 785 ms, sys: 788 ms, total: 1.57 s
# Wall time: 9min 10s

# %%
dt_lc_plot = plot_learning_curve_from_learning_curve_data('Decision Tree Learning Curve', *dt_lc_output)
# Out:
# train test sizes: [ 3181  6362  9543 12724 15906 19087 22268 25449 28630 31812]
# train scores means: [ 1.          0.99974851  0.99983234  0.99987425  0.99987426  0.99987426
#   0.99980241  0.99974066  0.9997066   0.99971709]
# train scores std: [  0.00000000e+00   1.25746621e-04   8.38310804e-05   6.28733103e-05
#    3.97620729e-05   4.19133442e-05   3.59259925e-05   5.33013477e-05
#    5.22760375e-05   4.44553490e-05]
# test scores mean: [ 0.32948735  0.35654013  0.37532318  0.3883244   0.39271993  0.39897795
#   0.40594711  0.40594345  0.41738679  0.41952053]
# test scores std: [ 0.0025976   0.00408164  0.00452506  0.0081652   0.00442613  0.00385974
#   0.00583116  0.00487027  0.00598284  0.00414727]

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2000)
# %time pca_model = pca.fit(all_inputs)

# %time pca_inputs = pca_model.transform(all_inputs)
pca_inputs.shape
# Out:
# CPU times: user 4min, sys: 4.48 s, total: 4min 4s
# Wall time: 54.9 s
# CPU times: user 33.1 s, sys: 734 ms, total: 33.8 s
# Wall time: 6 s
# (39774, 2000)

# %%
decision_tree_classifier = DecisionTreeClassifier()

# %time dt_lc_output = make_learning_curve(decision_tree_classifier, pca_inputs, all_classes, cv=5)
# Out:
# CPU times: user 1.27 s, sys: 1.53 s, total: 2.8 s
# Wall time: 20min 41s

# %%
dt_lc_plot = plot_learning_curve_from_learning_curve_data('Decision Tree Learning Curve', *dt_lc_output)
# Out:
# train test sizes: [ 3181  6362  9543 12724 15906 19087 22268 25449 28630 31812]
# train scores means: [ 1.          0.99974851  0.99983234  0.99987425  0.99987426  0.99987426
#   0.99980241  0.99974066  0.9997066   0.99971709]
# train scores std: [  0.00000000e+00   1.25746621e-04   8.38310804e-05   6.28733103e-05
#    3.97620729e-05   4.19133442e-05   3.59259925e-05   5.33013477e-05
#    5.22760375e-05   4.44553490e-05]
# test scores mean: [ 0.3231247   0.34864622  0.36848631  0.37980076  0.38859609  0.39271827
#   0.39465485  0.40559176  0.40999534  0.41469337]
# test scores std: [ 0.0045787   0.00412762  0.00678799  0.00905962  0.00447488  0.00306356
#   0.00580738  0.00299848  0.00702179  0.00304882]

# %% [markdown]
# ### Boosting

# %%
import seaborn as sb
from sklearn.dummy import DummyClassifier
from sklearn.cross_validation import cross_val_score
import numpy as np

def plot_model_accuracies(all_inputs, all_classes, cv=10, classifier=None, title=""):
    if classifier is None:
        classifier = DummyClassifier()
    cv_scores = cross_val_score(classifier, all_inputs, all_classes, cv=cv, n_jobs=1)
    sb.distplot(cv_scores, rug=True)
    plt.title('{}Average score: {}'.format(title, np.mean(cv_scores)))
    return (cv_scores, plt)

# %%
## plot dummy classifier
# %time dummy_cv, dummy_plot = plot_model_accuracies(all_inputs, all_classes, title="Dummy Classifier " )
# Out:
# CPU times: user 296 ms, sys: 2.44 s, total: 2.74 s
# Wall time: 26.6 s

# %%
from sklearn.ensemble import AdaBoostClassifier
decision_tree_params = {'max_features': 2000, 'criterion': 'gini'}
base_classifier = DecisionTreeClassifier(max_features=2000, criterion= 'gini')
# %time adda_cv, adda_plot = plot_model_accuracies(training_inputs, training_classes, classifier=AdaBoostClassifier(base_estimator=base_classifier), title="Ada Classifier " )
# Out:
# CPU times: user 3.81 s, sys: 3.05 s, total: 6.85 s
# Wall time: 2h 2min 38s

# %%
from learning_curve_helpers import make_learning_curve, plot_learning_curve_from_learning_curve_data

ada_classifier = AdaBoostClassifier(base_estimator=base_classifier)

# %time dt_lc_output = make_learning_curve(ada_classifier, training_inputs, training_classes, cv=3)
# Out:
# CPU times: user 4.15 s, sys: 3.22 s, total: 7.38 s
# Wall time: 1h 44min 49s

# %%
ab_lc_output = dt_lc_output

# %%
ab_lc_plot = plot_learning_curve_from_learning_curve_data('Adaboosted Decision Tree Learning Curve', *ab_lc_output)
# Out:
# train test sizes: [ 2385  4771  7157  9543 11929 14314 16700 19086 21472 23858]
# train scores means: [ 1.          1.          0.99995343  0.99982535  0.99986028  0.9998137
#   0.99982036  0.99980789  0.99973609  0.99974851]
# train scores std: [  0.00000000e+00   0.00000000e+00   6.58662178e-05   9.87958757e-05
#    7.90350441e-05   8.71328160e-05   9.77840217e-05   6.53473294e-05
#    5.80858387e-05   3.42231780e-05]
# test scores mean: [ 0.5119297   0.55397534  0.59779052  0.68446114  0.68999214  0.69786968
#   0.70965771  0.71440918  0.71742726  0.72376888]
# test scores std: [ 0.00253612  0.00636178  0.03859397  0.00249508  0.00406352  0.00399179
#   0.00580671  0.00203412  0.00286919  0.0024853 ]

# %% [markdown]
# ### Neural Nets

# %%
from sklearn.cross_validation import train_test_split
from sknn.mlp import Classifier, Layer  
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler


pipeline = Pipeline([
        ('min/max scalar', MinMaxScaler(feature_range=(0.0, 1.0))),
        ('neural network', Classifier(layers=[Layer("Softmax")], n_iter=1))
    ])

# nn = Classifier(layers=[Layer("Softmax")], n_iter=1)
nn_training_inputs = MinMaxScaler().fit_transform(training_inputs)


# (nn_training_inputs,
#  nn_testing_inputs,
#  nn_training_classes,
#  nn_testing_classes) = train_test_split(training_inputs, training_classes, train_size=100)


# %time pipeline.fit(nn_training_inputs, nn_training_classes)
# prediction = pipeline.predict(nn_testing_inputs)
# prediction
# Out:
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/sklearn/utils/validation.py:498: UserWarning: MinMaxScaler assumes floating point values as input, got int64
#   "got %s" % (estimator, X.dtype))

# %%
from scipy import stats
from sknn.mlp import Classifier, Layer  

nn = Classifier(layers=[Layer('Rectifier', units=50),Layer("Softmax")], n_iter=1000)
# %time nn.fit(nn_training_inputs, nn_training_classes)

classifier_accuracy = nn.score(testing_inputs, testing_classes)
classifier_accuracy
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 45.1 µs
# 0.46178984414278534

# %%
from scipy import stats
from sknn.mlp import Classifier, Layer  
from sklearn.grid_search import RandomizedSearchCV

nn = Classifier(layers=[Layer('Rectifier'),Layer("Softmax")], n_iter=25)

rs = RandomizedSearchCV(nn, param_distributions={
    'learning_rate': stats.uniform(0.001, 0.05),
    'hidden0__units': stats.randint(20, 3000),
    'hidden0__type': ["Rectifier", "Sigmoid", "Tanh"],
    'regularize':["L2",'']}, n_jobs=-1)

# %time rs.fit(nn_training_inputs, nn_training_classes)

print('Best score: {}'.format(rs.best_score_))
print('Best parameters: {}'.format(rs.best_params_))
# Out:
# CPU times: user 19 s, sys: 528 ms, total: 19.5 s
# Wall time: 6min 33s
# Best score: 0.44
# Best parameters: {'regularize': '', 'hidden0__units': 1116, 'learning_rate': 0.03308043610150833, 'hidden0__type': 'Rectifier'}
# INFO (theano.gof.compilelock): Waiting for existing lock by process '10472' (I am process '10470')
# INFO (theano.gof.compilelock): Waiting for existing lock by process '10472' (I am process '10471')
# INFO:theano.gof.compilelock:Waiting for existing lock by process '10472' (I am process '10470')
# INFO:theano.gof.compilelock:Waiting for existing lock by process '10472' (I am process '10471')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/dadmin/.theano/compiledir_Linux-3.16--amd64-x86_64-with-debian-8.1--2.7.10-64/lock_dir
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/dadmin/.theano/compiledir_Linux-3.16--amd64-x86_64-with-debian-8.1--2.7.10-64/lock_dir
# INFO:theano.gof.compilelock:To manually release the lock, delete /home/dadmin/.theano/compiledir_Linux-3.16--amd64-x86_64-with-debian-8.1--2.7.10-64/lock_dir
# INFO:theano.gof.compilelock:To manually release the lock, delete /home/dadmin/.theano/compiledir_Linux-3.16--amd64-x86_64-with-debian-8.1--2.7.10-64/lock_dir

# %%
from scipy import stats
from sknn.mlp import Classifier, Layer  
from sklearn.grid_search import RandomizedSearchCV

nn = Classifier(layers=[Layer('Rectifier'),Layer("Softmax")], n_iter=25)

rs = RandomizedSearchCV(nn, param_distributions={
    'learning_rate': stats.uniform(0.001, 0.05),
    'hidden0__units': stats.randint(800, 2500),
    'hidden0__type': ["Rectifier"],
    'regularize':["L2"]}, n_jobs=-1)

# %time rs.fit(nn_training_inputs, nn_training_classes)


print('Best score: {}'.format(rs.best_score_))
print('Best parameters: {}'.format(rs.best_params_))
# Out:
# CPU times: user 47.4 s, sys: 588 ms, total: 48 s
# Wall time: 6min 26s
# Best score: 0.44
# Best parameters: {'regularize': 'L2', 'hidden0__units': 2086, 'learning_rate': 0.006509020160665401, 'hidden0__type': 'Rectifier'}

# %%
from scipy import stats
from sknn.mlp import Classifier, Layer  
from sklearn.grid_search import RandomizedSearchCV

nn = Classifier(layers=[Layer('Rectifier'),Layer("Softmax")], n_iter=25)

rs = RandomizedSearchCV(nn, param_distributions={
    'learning_rate': stats.uniform(0.001, 0.05),
    'hidden0__units': stats.randint(800, 2500),
    'hidden0__type': ["Rectifier"],
    'regularize':[""]}, n_jobs=-1)

# %time rs.fit(nn_training_inputs, nn_training_classes)

print('Best score: {}'.format(rs.best_score_))
print('Best parameters: {}'.format(rs.best_params_))
# Out:
# CPU times: user 29.9 s, sys: 624 ms, total: 30.6 s
# Wall time: 5min 14s
# Best score: 0.43
# Best parameters: {'regularize': '', 'hidden0__units': 1733, 'learning_rate': 0.04154303794110034, 'hidden0__type': 'Rectifier'}

# %%
from sknn.mlp import Classifier, Layer
from learning_curve_helpers import make_learning_curve, plot_learning_curve_from_learning_curve_data

nn_classifier = Classifier(verbose=True, layers=[Layer('Rectifier', units=1116 ),Layer("Softmax")], n_iter=25, learning_rate=0.033)

# %time dt_lc_output = make_learning_curve(nn_classifier, nn_training_inputs, training_classes, cv=3, train_sizes=[100,200,300,400])

## this takes too long

# %%
svd_training_inputs?

# %%
from sklearn.preprocessing import MinMaxScaler

norm_svd_training_inputs = {}
norm_svd_testing_inputs = {}

for n in (svd_training_inputs.keys()):
    scaler = MinMaxScaler()
    scaler.fit(svd_training_inputs[n])
    norm_svd_training_inputs[n] = scaler.transform(svd_training_inputs[n])
    norm_svd_testing_inputs[n] = scaler.transform(svd_testing_inputs[n])

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.cross_validation import cross_val_score
print training_classes.shape
print training_classes.shape

cross_val_score(DecisionTreeClassifier() ,norm_svd_training_inputs[100], training_classes)
# Out:
# (35796,)
# (35796,)
# array([ 0.41057217,  0.40992123,  0.41467505])

# %%
from sknn.mlp import Classifier, Layer
from sklearn.grid_search import RandomizedSearchCV
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
import time

nn = Classifier(layers=[Layer('Rectifier'),Layer("Softmax")], n_iter=25)

rs = RandomizedSearchCV(nn, param_distributions={
    'learning_rate': stats.uniform(0.001, 0.05),
    'hidden0__units': stats.randint(100, 2000),
    'hidden0__type': ["Rectifier"],
    'regularize':["", 'L2']}, n_jobs=-1)

print nn

print "n_dimensions\ttrain_input_shape\ttrain_classes_shape\ttime\tscore\tparameters"

for n in sorted(svd_training_inputs.keys()):
    nn_train_inputs, nn_test_inputs, nn_train_classes, nn_test_classes = train_test_split(norm_svd_training_inputs[n], training_classes, train_size=800, test_size=100, random_state=42)
    #print nn_train_inputs_norm
#     print nn_train_inputs.shape
#     print nn_train_classes.shape
    print("{}\t{}\t{}\t".format(n, nn_train_inputs.shape, nn_train_classes.shape)),
    start = time.time()
    rs.fit(nn_train_inputs, nn_train_classes)
    print"{}\t{}\t{}\t{}".format(n, time.time() - start, rs.best_score_, rs.best_params_)
# Out:
# Classifier(batch_size=1, debug=False, dropout_rate=None, f_stable=0.001,
#       hidden0=<sknn.nn.Layer `Rectifier`: name=u'hidden0'>,
#       layers=[<sknn.nn.Layer `Rectifier`: name=u'hidden0'>, <sknn.nn.Layer `Softmax`: name=u'output'>],
#       learning_momentum=0.9, learning_rate=0.01, learning_rule=u'sgd',
#       loss_type=u'mse', mutator=None, n_iter=25, n_stable=50,
#       output=<sknn.nn.Layer `Softmax`: name=u'output'>, random_state=None,
#       regularize=None, valid_set=None, valid_size=0.0, verbose=None,
#       weight_decay=None)
# n_dimensions	train_input_shape	train_classes_shape	time	score	parameters
# 50	(800, 50)	(800,)	50	36.7777070999	0.51875	{'regularize': '', 'hidden0__units': 508, 'learning_rate': 0.024345743870148734, 'hidden0__type': 'Rectifier'}
# 100	(800, 100)	(800,)	100	64.8000659943	0.50125	{'regularize': '', 'hidden0__units': 976, 'learning_rate': 0.01136328220626472, 'hidden0__type': 'Rectifier'}
# 200	(800, 200)	(800,)	200	196.868660927	0.4475	{'regularize': 'L2', 'hidden0__units': 1308, 'learning_rate': 0.0074382934781212435, 'hidden0__type': 'Rectifier'}
# 300	(800, 300)	(800,)	300	101.915630817	0.375	{'regularize': 'L2', 'hidden0__units': 1550, 'learning_rate': 0.00491282548060557, 'hidden0__type': 'Rectifier'}
# 500	(800, 500)	(800,)	500	373.976859093	0.27125	{'regularize': '', 'hidden0__units': 488, 'learning_rate': 0.0011045891110248887, 'hidden0__type': 'Rectifier'}
# 750	(800, 750)	(800,)	750	465.040161133	0.225	{'regularize': 'L2', 'hidden0__units': 1142, 'learning_rate': 0.005907494018459752, 'hidden0__type': 'Rectifier'}
# 1000	(800, 1000)	(800,)	1000	869.592825174	0.21125	{'regularize': '', 'hidden0__units': 1648, 'learning_rate': 0.04068210619008095, 'hidden0__type': 'Rectifier'}

# %%
nn_param_dict = { 50: {'hidden0__units': 508, 'learning_rate': 0.024345743870148734, 'hidden0__type': 'Rectifier'},
              100: {'hidden0__units': 976, 'learning_rate': 0.01136328220626472, 'hidden0__type': 'Rectifier'},
              200: {'regularize': 'L2', 'hidden0__units': 1308, 'learning_rate': 0.0074382934781212435, 'hidden0__type': 'Rectifier'},      
              300: {'regularize': 'L2', 'hidden0__units': 1550, 'learning_rate': 0.00491282548060557, 'hidden0__type': 'Rectifier'},
              500: {'hidden0__units': 488, 'learning_rate': 0.0011045891110248887, 'hidden0__type': 'Rectifier'},
              750: {'regularize': 'L2', 'hidden0__units': 1142, 'learning_rate': 0.005907494018459752, 'hidden0__type': 'Rectifier'},
              1000: {'hidden0__units': 1648, 'learning_rate': 0.04068210619008095, 'hidden0__type': 'Rectifier'}
           }
print nn_params
# Out:
# {100: {'hidden0__units': 976, 'learning_rate': 0.01136328220626472, 'hidden0__type': 'Rectifier'}, 200: {'regularize': 'L2', 'hidden0__units': 1308, 'learning_rate': 0.0074382934781212435, 'hidden0__type': 'Rectifier'}, 300: {'regularize': 'L2', 'hidden0__units': 1550, 'learning_rate': 0.00491282548060557, 'hidden0__type': 'Rectifier'}, 750: {'regularize': 'L2', 'hidden0__units': 1142, 'learning_rate': 0.005907494018459752, 'hidden0__type': 'Rectifier'}, 1000: {'regularize': '', 'hidden0__units': 1648, 'learning_rate': 0.04068210619008095, 'hidden0__type': 'Rectifier'}, 50: {'hidden0__units': 508, 'learning_rate': 0.024345743870148734, 'hidden0__type': 'Rectifier'}, 500: {'regularize': '', 'hidden0__units': 488, 'learning_rate': 0.0011045891110248887, 'hidden0__type': 'Rectifier'}}

# %%
from learning_curve_helpers import make_learning_curve, plot_learning_curve_from_learning_curve_data
import numpy as np

nn_learning_curve_dict = {}

for n in sorted(svd_training_inputs.keys()):
    params = nn_param_dict[n]
    units = params['hidden0__units']
    params_cleansed = dict( (key, params[key]) for key in params if key != 'hidden0__units' or key != 'hidden0__type')
    del params_cleansed['hidden0__units']
    
    del params_cleansed['hidden0__type']
    
    print params_cleansed
    
    nn = Classifier(layers=[Layer('Rectifier', units=units), Layer("Softmax")], n_iter=50, **params_cleansed)
    start = time.time()
    # %time lc_output = make_learning_curve(nn, norm_svd_training_inputs[n], training_classes, cv=3)
    nn_learning_curve_dict[n] = {'lc_output' : lc_output, 'time': time.time() - start }
    print nn_learning_curve_dict[n]
print ""
print nn_learning_curve_dict
# Out:
# {'learning_rate': 0.024345743870148734}
# CPU times: user 1.36 s, sys: 1.18 s, total: 2.54 s
# Wall time: 19min 48s
# {'lc_output': (array([ 2385,  4771,  7157,  9543, 11929, 14315, 16701, 19087, 21473, 23859]), array([[ 0.62767296,  0.63857442,  0.63857442],
#        [ 0.68036051,  0.59987424,  0.59987424],
#        [ 0.64789716,  0.63895487,  0.63895487],
#        [ 0.62527507,  0.64267002,  0.64267002],
#        [ 0.66174868,  0.61857658,  0.63232459],
#        [ 0.62088718,  0.64903947,  0.6431715 ],
#        [ 0.60649063,  0.65091911,  0.63098018],
#        [ 0.64677529,  0.64714203,  0.63786871],
#        [ 0.65454291,  0.65482234,  0.62701998],
#        [ 0.63967476,  0.63799824,  0.65727818]]), array([[ 0.62767296,  0.63857442,  0.63857442],
#        [ 0.68036051,  0.59987424,  0.59987424],
#        [ 0.64789716,  0.63895487,  0.63895487],
#        [ 0.62527507,  0.64267002,  0.64267002],
#        [ 0.66174868,  0.61857658,  0.63232459],
#        [ 0.62088718,  0.64903947,  0.6431715 ],
#        [ 0.60649063,  0.65091911,  0.63098018],
#        [ 0.64677529,  0.64714203,  0.63786871],
#        [ 0.65454291,  0.65482234,  0.62701998],
#        [ 0.63967476,  0.63799824,  0.65727818]]), array([[ 0.53371869,  0.55941009,  0.56176101],
#        [ 0.59043311,  0.54809787,  0.55287212],
#        [ 0.59487308,  0.58823529,  0.59052411],
#        [ 0.57099774,  0.58857047,  0.58666667],
#        [ 0.60953338,  0.57926931,  0.5870021 ],
#        [ 0.58791991,  0.60817831,  0.60620545],
#        [ 0.5739298 ,  0.61680912,  0.59412998],
#        [ 0.60358549,  0.61018937,  0.59781971],
#        [ 0.61715674,  0.62024468,  0.6       ],
#        [ 0.60341794,  0.60750796,  0.62113208]]), array([[ 0.53371869,  0.55941009,  0.56176101],
#        [ 0.59043311,  0.54809787,  0.55287212],
#        [ 0.59487308,  0.58823529,  0.59052411],
#        [ 0.57099774,  0.58857047,  0.58666667],
#        [ 0.60953338,  0.57926931,  0.5870021 ],
#        [ 0.58791991,  0.60817831,  0.60620545],
#        [ 0.5739298 ,  0.61680912,  0.59412998],
#        [ 0.60358549,  0.61018937,  0.59781971],
#        [ 0.61715674,  0.62024468,  0.6       ],
#        [ 0.60341794,  0.60750796,  0.62113208]])), 'time': 1188.8348860740662}
# {'learning_rate': 0.01136328220626472}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-95971d8410c0> in <module>()
#      16     nn = Classifier(layers=[Layer('Rectifier', units=units), Layer("Softmax")], n_iter=50, **params_cleansed)
#      17     start = time.time()
# ---> 18     get_ipython().magic(u'time lc_output = make_learning_curve(nn, norm_svd_training_inputs[n], training_classes, cv=3, train_sizes=np.linspace(.1, 1.0, 6))')
#      19     nn_learning_curve_dict[n] = {'lc_output' : lc_output, 'time': time.time() - start }
#      20     print nn_learning_curve_dict[n]
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2334         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2335         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2336         return self.run_line_magic(magic_name, magic_arg_s)
#    2337
#    2338     #-------------------------------------------------------------------------
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2255                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2256             with self.builtin_trap:
# -> 2257                 result = fn(*args,**kwargs)
#    2258             return result
#    2259
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1165         else:
#    1166             st = clock2()
# -> 1167             exec(code, glob, local_ns)
#    1168             end = clock2()
#    1169             out = None
#
# <timed exec> in <module>()
#
# /home/dadmin/dev/machine-learning-supervised/learning_curve_helpers.pyc in make_learning_curve(classifier, X, y, cv, train_sizes)
#      24                                             cv=cv,
#      25                                             train_sizes=np.linspace(.1, 1.0, 10),
# ---> 26                                             n_jobs=-1)
#      27     return (train_sizes, train_scores, train_scores, test_scores, test_scores)
#      28
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/sklearn/learning_curve.pyc in learning_curve(estimator, X, y, train_sizes, cv, scoring, exploit_incremental_learning, n_jobs, pre_dispatch, verbose)
#     135             clone(estimator), X, y, scorer, train[:n_train_samples], test,
#     136             verbose, parameters=None, fit_params=None, return_train_score=True)
# --> 137             for train, test in cv for n_train_samples in train_sizes_abs)
#     138         out = np.array(out)[:, :2]
#     139         n_cv_folds = out.shape[0] // n_unique_ticks
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     664                 # consumption.
#     665                 self._iterating = False
# --> 666             self.retrieve()
#     667             # Make sure that we get a last message telling us we are done
#     668             elapsed_time = time.time() - self._start_time
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in retrieve(self)
#     530                             # We can now allow subprocesses again
#     531                             os.environ.pop('__JOBLIB_SPAWNED_PARALLEL__', 0)
# --> 532                         raise exception
#     533                     elif isinstance(exception, TransportableException):
#     534                         # Capture exception to add information on the local
#
# KeyboardInterrupt:

# %%
from learning_curve_helpers import make_learning_curve, plot_learning_curve_from_learning_curve_data
## ok that first learning curve was all the way to 1.0  -- more than I wanted to do ... Lets see the saturation 
from numpy import array
ab_lc_plot = plot_learning_curve_from_learning_curve_data('Neural Net Decision SVD 50 components Tree Learning Curve', array([ 2385,  4771,  7157,  9543, 11929, 14315, 16701, 19087, 21473, 23859]), array([[ 0.62767296,  0.63857442,  0.63857442],
       [ 0.68036051,  0.59987424,  0.59987424],
       [ 0.64789716,  0.63895487,  0.63895487],
       [ 0.62527507,  0.64267002,  0.64267002],
       [ 0.66174868,  0.61857658,  0.63232459],
       [ 0.62088718,  0.64903947,  0.6431715 ],
       [ 0.60649063,  0.65091911,  0.63098018],
       [ 0.64677529,  0.64714203,  0.63786871],
       [ 0.65454291,  0.65482234,  0.62701998],
       [ 0.63967476,  0.63799824,  0.65727818]]), array([[ 0.62767296,  0.63857442,  0.63857442],
       [ 0.68036051,  0.59987424,  0.59987424],
       [ 0.64789716,  0.63895487,  0.63895487],
       [ 0.62527507,  0.64267002,  0.64267002],
       [ 0.66174868,  0.61857658,  0.63232459],
       [ 0.62088718,  0.64903947,  0.6431715 ],
       [ 0.60649063,  0.65091911,  0.63098018],
       [ 0.64677529,  0.64714203,  0.63786871],
       [ 0.65454291,  0.65482234,  0.62701998],
       [ 0.63967476,  0.63799824,  0.65727818]]), array([[ 0.53371869,  0.55941009,  0.56176101],
       [ 0.59043311,  0.54809787,  0.55287212],
       [ 0.59487308,  0.58823529,  0.59052411],
       [ 0.57099774,  0.58857047,  0.58666667],
       [ 0.60953338,  0.57926931,  0.5870021 ],
       [ 0.58791991,  0.60817831,  0.60620545],
       [ 0.5739298 ,  0.61680912,  0.59412998],
       [ 0.60358549,  0.61018937,  0.59781971],
       [ 0.61715674,  0.62024468,  0.6       ],
       [ 0.60341794,  0.60750796,  0.62113208]]), array([[ 0.53371869,  0.55941009,  0.56176101],
       [ 0.59043311,  0.54809787,  0.55287212],
       [ 0.59487308,  0.58823529,  0.59052411],
       [ 0.57099774,  0.58857047,  0.58666667],
       [ 0.60953338,  0.57926931,  0.5870021 ],
       [ 0.58791991,  0.60817831,  0.60620545],
       [ 0.5739298 ,  0.61680912,  0.59412998],
       [ 0.60358549,  0.61018937,  0.59781971],
       [ 0.61715674,  0.62024468,  0.6       ],
       [ 0.60341794,  0.60750796,  0.62113208]]))
# Out:
# train test sizes: [ 2385  4771  7157  9543 11929 14315 16701 19087 21473 23859]
# train scores means: [ 0.6349406   0.626703    0.64193563  0.6368717   0.63754995  0.63769938
#   0.62946331  0.64392868  0.64546174  0.64498373]
# train scores std: [ 0.005139    0.03794159  0.00421544  0.00820006  0.01800807  0.01212699
#   0.01816954  0.00428766  0.01304079  0.00872039]
# test scores mean: [ 0.55162993  0.56380103  0.59121083  0.58207829  0.59193493  0.60076789
#   0.5949563   0.60386486  0.61246714  0.61068599]
# test scores std: [ 0.01270147  0.01893232  0.00275303  0.00787359  0.01283817  0.00912053
#   0.01751516  0.00505375  0.00890528  0.00757287]

# %%
from learning_curve_helpers import make_learning_curve, plot_learning_curve_from_learning_curve_data
import numpy as np

nn_learning_curve_dict = {}

for n in sorted(svd_training_inputs.keys()):
    params = nn_param_dict[n]
    units = params['hidden0__units']
    params_cleansed = dict( (key, params[key]) for key in params if key != 'hidden0__units' or key != 'hidden0__type')
    del params_cleansed['hidden0__units']
    
    del params_cleansed['hidden0__type']
    
    print params_cleansed
    
    nn = Classifier(layers=[Layer('Rectifier', units=units), Layer("Softmax")], n_iter=50, **params_cleansed)
    start = time.time()
    # %time lc_output = make_learning_curve(nn, norm_svd_training_inputs[n], training_classes, cv=3, train_sizes=np.linspace(.1, .5, 6))
    nn_learning_curve_dict[n] = {'lc_output' : lc_output, 'time': time.time() - start }
    print nn_learning_curve_dict[n]
print ""
print nn_learning_curve_dict

# %%
from learning_curve_helpers import make_learning_curve, plot_learning_curve_from_learning_curve_data
import numpy as np

nn_learning_curve_dict = {}

for n in sorted(svd_training_inputs.keys()):
    params = nn_param_dict[n]
    units = params['hidden0__units']
    params_cleansed = dict( (key, params[key]) for key in params if key != 'hidden0__units' or key != 'hidden0__type')
    del params_cleansed['hidden0__units']
    
    del params_cleansed['hidden0__type']
    
    print params_cleansed
    
    nn = Classifier(layers=[Layer('Rectifier', units=units), Layer("Softmax")], n_iter=50, **params_cleansed)
    start = time.time()
    # %time lc_output = make_learning_curve(nn, norm_svd_training_inputs[n], training_classes, cv=3, train_sizes=np.linspace(.1, 1.0, 10))
    nn_learning_curve_dict[n] = {'lc_output' : lc_output, 'time': time.time() - start }
    print nn_learning_curve_dict[n]
print ""
print nn_learning_curve_dict
# Out:
# {'learning_rate': 0.024345743870148734}
# CPU times: user 1.35 s, sys: 1.14 s, total: 2.49 s
# Wall time: 18min 43s
# {'lc_output': (array([ 2385,  4771,  7157,  9543, 11929, 14315, 16701, 19087, 21473, 23859]), array([[ 0.62767296,  0.63857442,  0.63857442],
#        [ 0.68036051,  0.59987424,  0.59987424],
#        [ 0.64789716,  0.63895487,  0.63895487],
#        [ 0.62527507,  0.64267002,  0.64267002],
#        [ 0.66174868,  0.61857658,  0.63232459],
#        [ 0.62088718,  0.64903947,  0.6431715 ],
#        [ 0.60649063,  0.65091911,  0.63098018],
#        [ 0.64677529,  0.64714203,  0.63786871],
#        [ 0.65454291,  0.65482234,  0.62701998],
#        [ 0.63967476,  0.63799824,  0.65727818]]), array([[ 0.62767296,  0.63857442,  0.63857442],
#        [ 0.68036051,  0.59987424,  0.59987424],
#        [ 0.64789716,  0.63895487,  0.63895487],
#        [ 0.62527507,  0.64267002,  0.64267002],
#        [ 0.66174868,  0.61857658,  0.63232459],
#        [ 0.62088718,  0.64903947,  0.6431715 ],
#        [ 0.60649063,  0.65091911,  0.63098018],
#        [ 0.64677529,  0.64714203,  0.63786871],
#        [ 0.65454291,  0.65482234,  0.62701998],
#        [ 0.63967476,  0.63799824,  0.65727818]]), array([[ 0.53371869,  0.55941009,  0.56176101],
#        [ 0.59043311,  0.54809787,  0.55287212],
#        [ 0.59487308,  0.58823529,  0.59052411],
#        [ 0.57099774,  0.58857047,  0.58666667],
#        [ 0.60953338,  0.57926931,  0.5870021 ],
#        [ 0.58791991,  0.60817831,  0.60620545],
#        [ 0.5739298 ,  0.61680912,  0.59412998],
#        [ 0.60358549,  0.61018937,  0.59781971],
#        [ 0.61715674,  0.62024468,  0.6       ],
#        [ 0.60341794,  0.60750796,  0.62113208]]), array([[ 0.53371869,  0.55941009,  0.56176101],
#        [ 0.59043311,  0.54809787,  0.55287212],
#        [ 0.59487308,  0.58823529,  0.59052411],
#        [ 0.57099774,  0.58857047,  0.58666667],
#        [ 0.60953338,  0.57926931,  0.5870021 ],
#        [ 0.58791991,  0.60817831,  0.60620545],
#        [ 0.5739298 ,  0.61680912,  0.59412998],
#        [ 0.60358549,  0.61018937,  0.59781971],
#        [ 0.61715674,  0.62024468,  0.6       ],
#        [ 0.60341794,  0.60750796,  0.62113208]])), 'time': 1123.2840549945831}
# {'learning_rate': 0.01136328220626472}
# CPU times: user 3.2 s, sys: 2.8 s, total: 6 s
# Wall time: 36min 5s
# {'lc_output': (array([ 2385,  4771,  7157,  9543, 11929, 14315, 16701, 19087, 21473, 23859]), array([[ 0.69266247,  0.68385744,  0.68385744],
#        [ 0.71955565,  0.66631733,  0.66631733],
#        [ 0.68604164,  0.68394579,  0.68394579],
#        [ 0.67567851,  0.69600754,  0.69600754],
#        [ 0.70391483,  0.67331713,  0.69863358],
#        [ 0.67963674,  0.69731051,  0.68718128],
#        [ 0.67828274,  0.69379079,  0.69660499],
#        [ 0.68999843,  0.71949494,  0.72106669],
#        [ 0.67228613,  0.71457179,  0.71634145],
#        [ 0.70501697,  0.70849575,  0.71968649]]), array([[ 0.69266247,  0.68385744,  0.68385744],
#        [ 0.71955565,  0.66631733,  0.66631733],
#        [ 0.68604164,  0.68394579,  0.68394579],
#        [ 0.67567851,  0.69600754,  0.69600754],
#        [ 0.70391483,  0.67331713,  0.69863358],
#        [ 0.67963674,  0.69731051,  0.68718128],
       [ 0.63793248,  0.67739232,  0.67656184],
       [ 0.66272933,  0.67655438,  0.68100629]]), array([[ 0.58649577,  0.59259259,  0.59337526],
       [ 0.63315741,  0.59787163,  0.60234801],
       [ 0.63114685,  0.6271996 ,  0.62750524],
       [ 0.62209935,  0.64035529,  0.63781971],
       [ 0.65887576,  0.62921066,  0.65014675],
       [ 0.63843512,  0.6561086 ,  0.64939203],
       [ 0.63407891,  0.66222557,  0.6518239 ],
       [ 0.64806903,  0.67940339,  0.68100629],
       [ 0.63793248,  0.67739232,  0.67656184],
       [ 0.66272933,  0.67655438,  0.68100629]]))
# Out:
# train test sizes: [ 2385  4771  7157  9543 11929 14315 16701 19087 21473 23859]
# train scores means: [ 0.68679245  0.68406344  0.68464441  0.6892312   0.69195518  0.68804284
#   0.68955951  0.71018669  0.70106646  0.7110664 ]
# train scores std: [ 0.00415073  0.02509678  0.00098799  0.0095832   0.01335429  0.00724096
#   0.00805622  0.01428967  0.02036358  0.00625859]
# test scores mean: [ 0.59082121  0.61112568  0.62861723  0.63342478  0.64607772  0.64797858
#   0.64937613  0.6694929   0.66396221  0.67343   ]
# test scores std: [ 0.00307519  0.0156856   0.00179306  0.00807491  0.01244782  0.00728406
#   0.01162045  0.01516309  0.01840892  0.00778174]

# %%
from learning_curve_helpers import plot_learning_curve_from_learning_curve_data
from sklearn.learning_curve import learning_curve
import numpy as np


def make_learning_curve(classifier, X, y, 
                        cv=None, 
                        train_sizes=np.linspace(.1, .4, 6) ):
    """
    Generate output of the learning curve using a given classifier and feature sets and class designation. 
    """
    
    cv = cv or StratifiedKFold(y, n_folds=10)
    
    train_sizes, train_scores, test_scores = learning_curve(classifier,
                                            X,
                                            y,
                                            cv=cv,
                                            train_sizes=train_sizes,
                                            n_jobs=-1)
    return (train_sizes, train_scores, train_scores)

nn_learning_curve_dict = {}

for n in sorted(svd_training_inputs.keys()):
    params = nn_param_dict[n]
    units = params['hidden0__units']
    params_cleansed = dict( (key, params[key]) for key in params if key != 'hidden0__units' or key != 'hidden0__type')
    del params_cleansed['hidden0__units']
    
    del params_cleansed['hidden0__type']
    
    print params_cleansed
    
    nn = Classifier(layers=[Layer('Rectifier', units=units), Layer("Softmax")], n_iter=50, **params_cleansed)
    start = time.time()
    # %time lc_output = make_learning_curve(nn, norm_svd_training_inputs[n], training_classes, cv=3, train_sizes=np.linspace(.1, .4, 6))
    nn_learning_curve_dict[n] = {'lc_output' : lc_output, 'time': time.time() - start }
    print nn_learning_curve_dict[n]
print ""
print nn_learning_curve_dict
# Out:
# {'learning_rate': 0.024345743870148734}
# CPU times: user 608 ms, sys: 740 ms, total: 1.35 s
# Wall time: 5min 14s
# {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.62767296,  0.63857442,  0.63857442],
#        [ 0.66151428,  0.66413414,  0.66413414],
#        [ 0.65472561,  0.61128049,  0.61128049],
#        [ 0.66047904,  0.61991018,  0.61991018],
#        [ 0.64681953,  0.63449211,  0.63449211],
#        [ 0.62527507,  0.64267002,  0.64267002]]), array([[ 0.62767296,  0.63857442,  0.63857442],
#        [ 0.66151428,  0.66413414,  0.66413414],
#        [ 0.65472561,  0.61128049,  0.61128049],
#        [ 0.66047904,  0.61991018,  0.61991018],
#        [ 0.64681953,  0.63449211,  0.63449211],
#        [ 0.62527507,  0.64267002,  0.64267002]])), 'time': 314.4179141521454}
# {'learning_rate': 0.01136328220626472}
# CPU times: user 1.28 s, sys: 1.54 s, total: 2.82 s
# Wall time: 9min 27s
# {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.69266247,  0.68385744,  0.68385744],
#        [ 0.69766833,  0.73198847,  0.73198847],
#        [ 0.70445884,  0.69988567,  0.69988567],
#        [ 0.71856287,  0.69116766,  0.69116766],
#        [ 0.70266272,  0.68626726,  0.68626726],
#        [ 0.67567851,  0.69600754,  0.69600754]]), array([[ 0.69266247,  0.68385744,  0.68385744],
#        [ 0.69766833,  0.73198847,  0.73198847],
#        [ 0.70445884,  0.69988567,  0.69988567],
#        [ 0.71856287,  0.69116766,  0.69116766],
#        [ 0.70266272,  0.68626726,  0.68626726],
#        [ 0.67567851,  0.69600754,  0.69600754]])), 'time': 567.0695300102234}
# {'regularize': 'L2', 'learning_rate': 0.0074382934781212435}

# %%
from learning_curve_helpers import plot_learning_curve_from_learning_curve_data
from sklearn.learning_curve import learning_curve
import numpy as np


def make_learning_curve(classifier, X, y, 
                        cv=None, 
                        train_sizes=np.linspace(.1, .4, 6) ):
    """
    Generate output of the learning curve using a given classifier and feature sets and class designation. 
    """
    
    cv = cv or StratifiedKFold(y, n_folds=10)
    
    train_sizes, train_scores, test_scores = learning_curve(classifier,
                                            X,
                                            y,
                                            cv=cv,
                                            train_sizes=train_sizes,
                                            n_jobs=-1)
    return (train_sizes, train_scores, test_scores)

nn_learning_curve_dict = {}

for n in sorted(svd_training_inputs.keys()):
    params = nn_param_dict[n]
    units = params['hidden0__units']
    params_cleansed = dict( (key, params[key]) for key in params if key != 'hidden0__units' or key != 'hidden0__type')
    del params_cleansed['hidden0__units']
    
    del params_cleansed['hidden0__type']
    
    if len()
    
    print params_cleansed
    
    nn = Classifier(layers=[Layer('Rectifier', units=units), Layer("Softmax")], n_iter=25, **params_cleansed)
    start = time.time()
    # %time lc_output = make_learning_curve(nn, norm_svd_training_inputs[n], training_classes, cv=3, train_sizes=np.linspace(.1, .4, 6))
    nn_learning_curve_dict[n] = {'lc_output' : lc_output, 'time': time.time() - start }
    print nn_learning_curve_dict[n]
print ""
print nn_learning_curve_dict
# Out:
# {'learning_rate': 0.024345743870148734}
# CPU times: user 580 ms, sys: 744 ms, total: 1.32 s
# Wall time: 2min 54s
# {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.61090147,  0.63060797,  0.63060797],
#        [ 0.61252292,  0.59889966,  0.59889966],
#        [ 0.61985518,  0.61128049,  0.61128049],
#        [ 0.60733533,  0.58008982,  0.58008982],
#        [ 0.60145464,  0.61550789,  0.61550789],
#        [ 0.6137483 ,  0.6099759 ,  0.6099759 ]]), array([[ 0.54636843,  0.57214681,  0.56737945],
#        [ 0.56437966,  0.55211999,  0.561174  ],
#        [ 0.57753204,  0.5837942 ,  0.5893501 ],
#        [ 0.57677808,  0.54751131,  0.55396226],
#        [ 0.56521739,  0.58102899,  0.58859539],
#        [ 0.57920751,  0.58278867,  0.58943396]])), 'time': 174.62896299362183}
# {'learning_rate': 0.01136328220626472}
# CPU times: user 1.15 s, sys: 1.45 s, total: 2.6 s
# Wall time: 5min 14s
# {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.63144654,  0.69853249,  0.69853249],
#        [ 0.68928478,  0.66544407,  0.66544407],
#        [ 0.70083841,  0.6413872 ,  0.6413872 ],
#        [ 0.68398204,  0.65434132,  0.65434132],
#        [ 0.6283284 ,  0.67233728,  0.67233728],
#        [ 0.67913654,  0.64843341,  0.64843341]]), array([[ 0.54444165,  0.61840121,  0.61819706],
#        [ 0.61497864,  0.60859729,  0.61433962],
#        [ 0.63885398,  0.60373722,  0.60771488],
#        [ 0.64237246,  0.61530082,  0.61526205],
#        [ 0.59378403,  0.62753477,  0.63253669],
#        [ 0.6394404 ,  0.62200436,  0.62280922]])), 'time': 314.09610199928284}
# {'regularize': 'L2', 'learning_rate': 0.0074382934781212435}
# CPU times: user 3.53 s, sys: 3.14 s, total: 6.67 s
# Wall time: 19min 29s
# {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.69559748,  0.74339623,  0.74339623],
#        [ 0.72674876,  0.69400052,  0.69400052],
#        [ 0.73971037,  0.65529726,  0.65529726],
#        [ 0.71122754,  0.71212575,  0.71212575],
#        [ 0.60811144,  0.69933432,  0.69933432],
#        [ 0.71570785,  0.66991512,  0.66991512]]), array([[ 0.57761582,  0.64429361,  0.6427673 ],
#        [ 0.6313144 ,  0.62091503,  0.62649895],
#        [ 0.66800704,  0.61923915,  0.6208805 ],
#        [ 0.66390215,  0.65954416,  0.66415094],
#        [ 0.56471475,  0.65728172,  0.65878407],
#        [ 0.67294965,  0.63608178,  0.63698113]])), 'time': 1169.1475911140442}
# {'regularize': 'L2', 'learning_rate': 0.00491282548060557}
# CPU times: user 5.59 s, sys: 5.06 s, total: 10.7 s
# Wall time: 33min 51s
# {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.64737945,  0.75345912,  0.75345912],
#        [ 0.72753471,  0.70631386,  0.70631386],
#        [ 0.7503811 ,  0.66101372,  0.66101372],
#        [ 0.73173653,  0.74011976,  0.74011976],
#        [ 0.6688856 ,  0.70907298,  0.70907298],
#        [ 0.73163575,  0.69024416,  0.69024416]]), array([[ 0.51997989,  0.650243  ,  0.6478826 ],
#        [ 0.62729329,  0.62812133,  0.62951782],
#        [ 0.6731172 ,  0.61672532,  0.6118239 ],
#        [ 0.67194437,  0.6806603 ,  0.68125786],
#        [ 0.62109408,  0.65996313,  0.6608805 ],
#        [ 0.68224847,  0.64412603,  0.65039832]])), 'time': 2031.3319070339203}
# {'regularize': '', 'learning_rate': 0.0011045891110248887}
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-60-b041d66459fa> in <module>()
#      33     print params_cleansed
#      34
# ---> 35     nn = Classifier(layers=[Layer('Rectifier', units=units), Layer("Softmax")], n_iter=25, **params_cleansed)
#      36     start = time.time()
#      37     get_ipython().magic(u'time lc_output = make_learning_curve(nn, norm_svd_training_inputs[n], training_classes, cv=3, train_sizes=np.linspace(.1, .4, 6))')
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/sknn/nn.pyc in __init__(self, layers, random_state, learning_rule, learning_rate, learning_momentum, regularize, weight_decay, dropout_rate, batch_size, n_iter, n_stable, f_stable, valid_set, valid_size, loss_type, mutator, debug, verbose, **params)
#     386         # Basic checking of the freeform string options.
#     387         assert regularize in (None, 'L1', 'L2', 'dropout'),\
# --> 388             "Unknown type of regularization specified: %s." % regularize
#     389         assert loss_type in ('mse', 'mae'),\
#     390             "Unknown loss function type specified: %s." % loss_type
#
# AssertionError: Unknown type of regularization specified: .

# %%
from learning_curve_helpers import plot_learning_curve_from_learning_curve_data
from sklearn.learning_curve import learning_curve
import numpy as np


def make_learning_curve(classifier, X, y, 
                        cv=None, 
                        train_sizes=np.linspace(.1, .4, 6) ):
    """
    Generate output of the learning curve using a given classifier and feature sets and class designation. 
    """
    
    cv = cv or StratifiedKFold(y, n_folds=10)
    
    train_sizes, train_scores, test_scores = learning_curve(classifier,
                                            X,
                                            y,
                                            cv=cv,
                                            train_sizes=train_sizes,
                                            n_jobs=-1)
    return (train_sizes, train_scores, test_scores)

nn_learning_curve_dict = {}

for n in sorted(svd_training_inputs.keys()):
    params = nn_param_dict[n]
    units = params['hidden0__units']
    params_cleansed = dict( (key, params[key]) for key in params if key != 'hidden0__units' or key != 'hidden0__type')
    del params_cleansed['hidden0__units']
    
    del params_cleansed['hidden0__type']
    
    
    print params_cleansed
    
    nn = Classifier(layers=[Layer('Rectifier', units=units), Layer("Softmax")], n_iter=25, **params_cleansed)
    start = time.time()
    # %time lc_output = make_learning_curve(nn, norm_svd_training_inputs[n], training_classes, cv=3, train_sizes=np.linspace(.1, .4, 6))
    nn_learning_curve_dict[n] = {'lc_output' : lc_output, 'time': time.time() - start }
    print nn_learning_curve_dict[n]
print ""
print nn_learning_curve_dict
# Out:
# {'learning_rate': 0.024345743870148734}
# CPU times: user 596 ms, sys: 648 ms, total: 1.24 s
# Wall time: 2min 33s
# {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.61090147,  0.63060797,  0.63060797],
#        [ 0.61252292,  0.59889966,  0.59889966],
#        [ 0.61985518,  0.61128049,  0.61128049],
#        [ 0.60733533,  0.58008982,  0.58008982],
#        [ 0.60145464,  0.61550789,  0.61550789],
#        [ 0.6137483 ,  0.6099759 ,  0.6099759 ]]), array([[ 0.54636843,  0.57214681,  0.56737945],
#        [ 0.56437966,  0.55211999,  0.561174  ],
#        [ 0.57753204,  0.5837942 ,  0.5893501 ],
#        [ 0.57677808,  0.54751131,  0.55396226],
#        [ 0.56521739,  0.58102899,  0.58859539],
#        [ 0.57920751,  0.58278867,  0.58943396]])), 'time': 153.41510605812073}
# {'learning_rate': 0.01136328220626472}
# CPU times: user 1.2 s, sys: 1.51 s, total: 2.71 s
# Wall time: 5min 2s
# {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.63144654,  0.69853249,  0.69853249],
#        [ 0.68928478,  0.66544407,  0.66544407],
#        [ 0.70083841,  0.6413872 ,  0.6413872 ],
#        [ 0.68398204,  0.65434132,  0.65434132],
#        [ 0.6283284 ,  0.67233728,  0.67233728],
#        [ 0.67913654,  0.64843341,  0.64843341]]), array([[ 0.54444165,  0.61840121,  0.61819706],
#        [ 0.61497864,  0.60859729,  0.61433962],
#        [ 0.63885398,  0.60373722,  0.60771488],
#        [ 0.64237246,  0.61530082,  0.61526205],
#        [ 0.59378403,  0.62753477,  0.63253669],
#        [ 0.6394404 ,  0.62200436,  0.62280922]])), 'time': 302.71145510673523}
# {'regularize': 'L2', 'learning_rate': 0.0074382934781212435}
# CPU times: user 3.5 s, sys: 2.93 s, total: 6.43 s
# Wall time: 18min 24s
# {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.69559748,  0.74339623,  0.74339623],
#        [ 0.72674876,  0.69400052,  0.69400052],
#        [ 0.73971037,  0.65529726,  0.65529726],
#        [ 0.71122754,  0.71212575,  0.71212575],
#        [ 0.60811144,  0.69933432,  0.69933432],
#        [ 0.71570785,  0.66991512,  0.66991512]]), array([[ 0.57761582,  0.64429361,  0.6427673 ],
#        [ 0.6313144 ,  0.62091503,  0.62649895],
#        [ 0.66800704,  0.61923915,  0.6208805 ],
#        [ 0.66390215,  0.65954416,  0.66415094],
#        [ 0.56471475,  0.65728172,  0.65878407],
#        [ 0.67294965,  0.63608178,  0.63698113]])), 'time': 1104.6512088775635}
# {'regularize': 'L2', 'learning_rate': 0.00491282548060557}
# CPU times: user 5.6 s, sys: 4.92 s, total: 10.5 s
# Wall time: 33min 51s
# {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.64737945,  0.75345912,  0.75345912],
#        [ 0.72753471,  0.70631386,  0.70631386],
#        [ 0.7503811 ,  0.66101372,  0.66101372],
#        [ 0.73173653,  0.74011976,  0.74011976],
#        [ 0.6688856 ,  0.70907298,  0.70907298],
#        [ 0.73163575,  0.69024416,  0.69024416]]), array([[ 0.51997989,  0.650243  ,  0.6478826 ],
#        [ 0.62729329,  0.62812133,  0.62951782],
#        [ 0.6731172 ,  0.61672532,  0.6118239 ],
#        [ 0.67194437,  0.6806603 ,  0.68125786],
#        [ 0.62109408,  0.65996313,  0.6608805 ],
#        [ 0.68224847,  0.64412603,  0.65039832]])), 'time': 2031.5553078651428}
# {'learning_rate': 0.0011045891110248887}
# CPU times: user 1.08 s, sys: 636 ms, total: 1.72 s
# Wall time: 14min 14s
# {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.52620545,  0.5408805 ,  0.5408805 ],
#        [ 0.62352633,  0.58763427,  0.58763427],
#        [ 0.69550305,  0.55811738,  0.55811738],
#        [ 0.66946108,  0.69580838,  0.69580838],
#        [ 0.66913215,  0.65014793,  0.65014793],
#        [ 0.7058577 ,  0.68196584,  0.68196584]]), array([[ 0.44768367,  0.46564438,  0.46540881],
#        [ 0.55290274,  0.53200938,  0.53551363],
#        [ 0.63424646,  0.52538964,  0.52570231],
#        [ 0.62343973,  0.65141612,  0.65039832],
#        [ 0.62310463,  0.61236802,  0.61450734],
#        [ 0.66373461,  0.64513156,  0.64888889]])), 'time': 854.9815158843994}
# {'regularize': 'L2', 'learning_rate': 0.005907494018459752}
# CPU times: user 3.74 s, sys: 1.66 s, total: 5.4 s
# Wall time: 58min 38s
# {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.35681342,  0.65073375,  0.65073375],
#        [ 0.66230024,  0.60073356,  0.60073356],
#        [ 0.65053354,  0.53696646,  0.53696646],
#        [ 0.63592814,  0.7239521 ,  0.7239521 ],
#        [ 0.58234714,  0.6622288 ,  0.6622288 ],
#        [ 0.69433092,  0.67064864,  0.67064864]]), array([[ 0.24076401,  0.54759511,  0.55631027],
#        [ 0.54879786,  0.52874141,  0.52553459],
#        [ 0.56387702,  0.49698341,  0.49442348],
#        [ 0.57225434,  0.66356628,  0.66213836],
#        [ 0.52710061,  0.60742417,  0.60654088],
#        [ 0.64027813,  0.61882018,  0.61870021]])), 'time': 3518.662462949753}
# {'learning_rate': 0.04068210619008095}
# CPU times: user 8.53 s, sys: 2.75 s, total: 11.3 s
# Wall time: 1h 44min 30s
# {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.14926625,  0.19035639,  0.19035639],
#        [ 0.19229762,  0.19884726,  0.19884726],
#        [ 0.19588415,  0.19798018,  0.19798018],
#        [ 0.19266467,  0.19715569,  0.19715569],
#        [ 0.19267751,  0.16629684,  0.16629684],
#        [ 0.19354501,  0.1626323 ,  0.1626323 ]]), array([[ 0.16201726,  0.19733534,  0.19748428],
#        [ 0.19728575,  0.19733534,  0.19748428],
#        [ 0.19728575,  0.19733534,  0.19748428],
#        [ 0.19728575,  0.19733534,  0.19748428],
#        [ 0.19736952,  0.16205799,  0.16209644],
#        [ 0.19728575,  0.16205799,  0.16209644]])), 'time': 6270.148718833923}
#
# {100: {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.63144654,  0.69853249,  0.69853249],
#        [ 0.68928478,  0.66544407,  0.66544407],
#        [ 0.70083841,  0.6413872 ,  0.6413872 ],
#        [ 0.68398204,  0.65434132,  0.65434132],
#        [ 0.6283284 ,  0.67233728,  0.67233728],
#        [ 0.67913654,  0.64843341,  0.64843341]]), array([[ 0.54444165,  0.61840121,  0.61819706],
#        [ 0.61497864,  0.60859729,  0.61433962],
#        [ 0.63885398,  0.60373722,  0.60771488],
#        [ 0.64237246,  0.61530082,  0.61526205],
#        [ 0.59378403,  0.62753477,  0.63253669],
#        [ 0.6394404 ,  0.62200436,  0.62280922]])), 'time': 302.71145510673523}, 200: {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.69559748,  0.74339623,  0.74339623],
#        [ 0.72674876,  0.69400052,  0.69400052],
#        [ 0.73971037,  0.65529726,  0.65529726],
#        [ 0.71122754,  0.71212575,  0.71212575],
#        [ 0.60811144,  0.69933432,  0.69933432],
#        [ 0.71570785,  0.66991512,  0.66991512]]), array([[ 0.57761582,  0.64429361,  0.6427673 ],
#        [ 0.6313144 ,  0.62091503,  0.62649895],
#        [ 0.66800704,  0.61923915,  0.6208805 ],
#        [ 0.66390215,  0.65954416,  0.66415094],
#        [ 0.56471475,  0.65728172,  0.65878407],
#        [ 0.67294965,  0.63608178,  0.63698113]])), 'time': 1104.6512088775635}, 300: {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.64737945,  0.75345912,  0.75345912],
#        [ 0.72753471,  0.70631386,  0.70631386],
#        [ 0.7503811 ,  0.66101372,  0.66101372],
#        [ 0.73173653,  0.74011976,  0.74011976],
#        [ 0.6688856 ,  0.70907298,  0.70907298],
#        [ 0.73163575,  0.69024416,  0.69024416]]), array([[ 0.51997989,  0.650243  ,  0.6478826 ],
#        [ 0.62729329,  0.62812133,  0.62951782],
#        [ 0.6731172 ,  0.61672532,  0.6118239 ],
#        [ 0.67194437,  0.6806603 ,  0.68125786],
#        [ 0.62109408,  0.65996313,  0.6608805 ],
#        [ 0.68224847,  0.64412603,  0.65039832]])), 'time': 2031.5553078651428}, 750: {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.35681342,  0.65073375,  0.65073375],
#        [ 0.66230024,  0.60073356,  0.60073356],
#        [ 0.65053354,  0.53696646,  0.53696646],
#        [ 0.63592814,  0.7239521 ,  0.7239521 ],
#        [ 0.58234714,  0.6622288 ,  0.6622288 ],
#        [ 0.69433092,  0.67064864,  0.67064864]]), array([[ 0.24076401,  0.54759511,  0.55631027],
#        [ 0.54879786,  0.52874141,  0.52553459],
#        [ 0.56387702,  0.49698341,  0.49442348],
#        [ 0.57225434,  0.66356628,  0.66213836],
#        [ 0.52710061,  0.60742417,  0.60654088],
#        [ 0.64027813,  0.61882018,  0.61870021]])), 'time': 3518.662462949753}, 1000: {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.14926625,  0.19035639,  0.19035639],
#        [ 0.19229762,  0.19884726,  0.19884726],
#        [ 0.19588415,  0.19798018,  0.19798018],
#        [ 0.19266467,  0.19715569,  0.19715569],
#        [ 0.19267751,  0.16629684,  0.16629684],
#        [ 0.19354501,  0.1626323 ,  0.1626323 ]]), array([[ 0.16201726,  0.19733534,  0.19748428],
#        [ 0.19728575,  0.19733534,  0.19748428],
#        [ 0.19728575,  0.19733534,  0.19748428],
#        [ 0.19728575,  0.19733534,  0.19748428],
#        [ 0.19736952,  0.16205799,  0.16209644],
#        [ 0.19728575,  0.16205799,  0.16209644]])), 'time': 6270.148718833923}, 50: {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.61090147,  0.63060797,  0.63060797],
#        [ 0.61252292,  0.59889966,  0.59889966],
#        [ 0.61985518,  0.61128049,  0.61128049],
#        [ 0.60733533,  0.58008982,  0.58008982],
#        [ 0.60145464,  0.61550789,  0.61550789],
#        [ 0.6137483 ,  0.6099759 ,  0.6099759 ]]), array([[ 0.54636843,  0.57214681,  0.56737945],
#        [ 0.56437966,  0.55211999,  0.561174  ],
#        [ 0.57753204,  0.5837942 ,  0.5893501 ],
#        [ 0.57677808,  0.54751131,  0.55396226],
#        [ 0.56521739,  0.58102899,  0.58859539],
#        [ 0.57920751,  0.58278867,  0.58943396]])), 'time': 153.41510605812073}, 500: {'lc_output': (array([2385, 3817, 5248, 6680, 8112, 9543]), array([[ 0.52620545,  0.5408805 ,  0.5408805 ],
#        [ 0.62352633,  0.58763427,  0.58763427],
#        [ 0.69550305,  0.55811738,  0.55811738],
#        [ 0.66946108,  0.69580838,  0.69580838],
#        [ 0.66913215,  0.65014793,  0.65014793],
#        [ 0.7058577 ,  0.68196584,  0.68196584]]), array([[ 0.44768367,  0.46564438,  0.46540881],
#        [ 0.55290274,  0.53200938,  0.53551363],
#        [ 0.63424646,  0.52538964,  0.52570231],
#        [ 0.62343973,  0.65141612,  0.65039832],
#        [ 0.62310463,  0.61236802,  0.61450734],
#        [ 0.66373461,  0.64513156,  0.64888889]])), 'time': 854.9815158843994}}

# %%
import pickle
with open('nn_learning_curve_dict', 'wb') as data_file:
    pickle.dump(nn_learning_curve_dict, data_file)

# %%
from learning_curve_helpers import plot_learning_curve_from_learning_curve_data
def plot_learning_curve_from_learning_curve_data(title='Learning Curve:', *lc_args):
    """
    Generate a simple plot of the test and training learning curve with the our

    Parameters
    ----------
    title : string
        Title for the chart.
    *lc_args : output of shape: train_sizes, 
                                train_scores_mean, 
                                train_scores_std, 
                                test_scores_mean, 
                                test_scores_std
  
    """
    
    train_sizes, train_scores, test_scores = lc_args
    
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    print "train test sizes: {}".format(train_sizes)
    print "train scores means: {}".format(train_scores_mean)
    print "train scores std: {}".format(train_scores_std)
    print "test scores mean: {}".format(test_scores_mean)
    print "test scores std: {}".format(test_scores_std)
    
    plt.figure()
    plt.title(title)
#     if ylim is not None:
#         plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt



# make make learning curve plots

for n in sorted(nn_learning_curve_dict):
    lc_output = nn_learning_curve_dict[n]['lc_output']
    title = 'Neural Net\n(n_components={} training_time={:.2f}s iterations=25)\nLearning Curve'.format(n, nn_learning_curve_dict[n]['time'] )
    plot = plot_learning_curve_from_learning_curve_data(title, *lc_output)
# Out:
# train test sizes: [2385 3817 5248 6680 8112 9543]
# train scores means: [ 0.62403913  0.60344075  0.61413872  0.58917166  0.61082347  0.61123336]
# train scores std: [ 0.00928973  0.00642207  0.00404215  0.01284366  0.00662477  0.00177833]
# test scores mean: [ 0.5619649   0.55922455  0.58355878  0.55941722  0.57828059  0.58381005]
# test scores std: [ 0.01119879  0.00519135  0.00482757  0.0125553   0.00973988  0.00423694]
# train test sizes: [2385 3817 5248 6680 8112 9543]
# train scores means: [ 0.67617051  0.67339097  0.66120427  0.66422156  0.65766765  0.65866778]
# train scores std: [ 0.03162462  0.01123862  0.02802557  0.01397277  0.02074598  0.0144736 ]
# test scores mean: [ 0.59367997  0.61263852  0.6167687   0.62431178  0.61795183  0.62808466]
# test scores std: [ 0.03481685  0.00286946  0.01570086  0.01277084  0.01721078  0.00803644]
# train test sizes: [2385 3817 5248 6680 8112 9543]
# train scores means: [ 0.72746331  0.7049166   0.68343496  0.71182635  0.66892669  0.68517936]
# train scores std: [ 0.02253254  0.01543766  0.03979272  0.00042342  0.04300288  0.0215869 ]
# test scores mean: [ 0.62155891  0.6262428   0.63604223  0.66253242  0.62692685  0.64867086]
# test scores std: [ 0.03107871  0.00424939  0.02261246  0.00211546  0.04399487  0.01717163]
# train test sizes: [2385 3817 5248 6680 8112 9543]
# train scores means: [ 0.71809923  0.71338748  0.69080285  0.73732535  0.69567719  0.70404136]
# train scores std: [ 0.05000643  0.01000361  0.04212819  0.00395189  0.01894451  0.01951219]
# test scores mean: [ 0.60603517  0.62831081  0.63388881  0.67795418  0.64731257  0.65892427]
# test scores std: [ 0.0608579   0.00091799  0.02781074  0.00425657  0.01854306  0.0166903 ]
# train test sizes: [2385 3817 5248 6680 8112 9543]
# train scores means: [ 0.53598882  0.59959829  0.6039126   0.68702595  0.656476    0.68992979]
# train scores std: [ 0.00691789  0.01691968  0.06476423  0.01242024  0.00894925  0.01126273]
# test scores mean: [ 0.45957895  0.54014192  0.56177947  0.64175139  0.61666     0.65258502]
# test scores std: [ 0.00841178  0.00913597  0.05124206  0.01295497  0.00463998  0.00803179]
# train test sizes: [2385 3817 5248 6680 8112 9543]
# train scores means: [ 0.55276031  0.62125579  0.57482215  0.69461078  0.63560158  0.67854274]
# train scores std: [ 0.13855537  0.02902281  0.05353603  0.04149489  0.03765657  0.01116393]
# test scores mean: [ 0.44822313  0.53435795  0.51842797  0.63265299  0.58035522  0.62593284]
# test scores std: [ 0.14673889  0.01029414  0.03215432  0.04271228  0.03765842  0.01014377]
# train test sizes: [2385 3817 5248 6680 8112 9543]
# train scores means: [ 0.17665968  0.19666405  0.1972815   0.19565868  0.1750904   0.17293653]
# train scores std: [ 0.01937008  0.00308753  0.00098808  0.00211709  0.01243597  0.01457239]
# test scores mean: [ 0.18561229  0.19736846  0.19736846  0.19736846  0.17384131  0.17381339]
# test scores std: [  1.66843204e-02   8.43624543e-05   8.43624543e-05   8.43624543e-05
#    1.66369631e-02   1.65974721e-02]

# %%
print 1
# Out:
# 1

# %%
from sknn.mlp import Layer, Classifier
from sklearn.cross_validation import StratifiedKFold, train_test_split
import time
# The 300 component at around 5000 or 6000 training examples was selected for further training

cv =  StratifiedKFold( training_classes )

nn_n300_finished_list = []

print 'starting'
for training_index, testing_index in cv: 
    nn = Classifier(layers=[Layer('Rectifier', units=1550), Layer("Softmax")], n_iter=150, learning_rate=0.00491282548060557)
    train_in, test_in, train_out, test_out = train_test_split(norm_svd_training_inputs[300][training_index], training_classes[training_index], train_size=5000)
    print train_in.shape
    print test_in.shape
    start = time.time()
    # %time nn.fit(train_in, train_out)
    duration = start - time.time()
    print 'duration: ' + str(duration)
    training_accuracy = nn.score(train_in, train_out)
    print training_accuracy
    testing_accuracy = nn.score(test_in, test_out)
    print testing_accuracy
    nn_n300_finished_list.append({ 'training_num':5000 'classifier':nn, 'testing_score':testing_accuracy, 'training_score':training_accuracy, 'time':duration })
# Out:
# starting
# (5000, 300)
# (18859, 300)
# CPU times: user 8min 36s, sys: 196 ms, total: 8min 36s
# Wall time: 8min 36s
# duration: -516.528728008
# 0.8444
# 0.675115329551
# (5000, 300)
# (18862, 300)
# CPU times: user 8min 34s, sys: 156 ms, total: 8min 34s
# Wall time: 8min 33s
# duration: -513.895125866
# 0.8406
# 0.662602057046
# (5000, 300)
# (18871, 300)
# CPU times: user 8min 34s, sys: 132 ms, total: 8min 35s
# Wall time: 8min 34s
# duration: -514.532691002
# 0.8378
# 0.66482963277
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-51e75808dbd1> in <module>()
#      23     print testing_accuracy
#      24     nn_n300_finished_list.append({ 'classifier':nn, 'testing_score':testing_accuracy, 'training_score':training_accuracy, 'time':duration })
# ---> 25 classifier_accuracy = decision_tree_classifier.score(testing_inputs, testing_classes)
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/sklearn/base.pyc in score(self, X, y, sample_weight)
#     293         """
#     294         from .metrics import accuracy_score
# --> 295         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     296
#     297
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/sklearn/tree/tree.pyc in predict(self, X, check_input)
#     349                              " match the input. Model n_features is %s and "
#     350                              " input n_features is %s "
# --> 351                              % (self.n_features_, n_features))
#     352
#     353         proba = self.tree_.predict(X)
#
# ValueError: Number of features of the model must  match the input. Model n_features is 100 and  input n_features is 3010

# %%
for e in nn_n300_finished_list:
    e['training_num'] = 5000

# %%
from sknn.mlp import Layer, Classifier
from sklearn.cross_validation import StratifiedKFold, train_test_split
import time
# The 500 component at around 5000 or 6000 training examples was selected for further training

cv =  StratifiedKFold( training_classes )

nn_n500_finished_list = []

print 'starting'
for training_index, testing_index in cv: 
    nn = Classifier(layers=[Layer('Rectifier', units=1550), Layer("Softmax")], n_iter=150, learning_rate=0.00491282548060557)
    train_in, test_in, train_out, test_out = train_test_split(norm_svd_training_inputs[500][training_index], training_classes[training_index], train_size=5000)
    print train_in.shape
    print test_in.shape
    start = time.time()
    # %time nn.fit(train_in, train_out)
    duration = start - time.time()
    print 'duration: ' + str(duration)
    training_accuracy = nn.score(train_in, train_out)
    print training_accuracy
    testing_accuracy = nn.score(test_in, test_out)
    print testing_accuracy
    nn_n500_finished_list.append({ 'training_num':5000 , 'classifier':nn, 'testing_score':testing_accuracy, 'training_score':training_accuracy, 'time':duration })
# Out:
# starting
# (5000, 500)
# (18859, 500)
# CPU times: user 14min 46s, sys: 296 ms, total: 14min 47s
# Wall time: 14min 46s
# duration: -886.556138039
# 0.8906
# 0.683334217085
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-7539e5a567cb> in <module>()
#      22     testing_accuracy = nn.score(test_in, test_out)
#      23     print testing_accuracy
# ---> 24     nn_500_finished_list.append({ 'training_num':5000 , 'classifier':nn, 'testing_score':testing_accuracy, 'training_score':training_accuracy, 'time':duration })
#
# NameError: name 'nn_500_finished_list' is not defined

# %%
    nn_n500_finished_list.append({ 'training_num':5000 , 'classifier':nn, 'testing_score':testing_accuracy, 'training_score':training_accuracy, 'time':duration })

# %%
from learning_curve_helpers import make_learning_curve, plot_learning_curve_from_learning_curve_data
import numpy as np

nn_learning_curve_dict = {}

for n in sorted(svd_training_inputs.keys()):
    params = nn_param_dict[n]
    units = params['hidden0__units']
    params_cleansed = dict( (key, params[key]) for key in params if key != 'hidden0__units' or key != 'hidden0__type')
    del params_cleansed['hidden0__units']
    
    del params_cleansed['hidden0__type']
    
    print params_cleansed
    
    nn = Classifier(layers=[Layer('Rectifier', units=units), Layer("Softmax")], n_iter=50, **params_cleansed)
    start = time.time()
    # %time lc_output = make_learning_curve(nn, norm_svd_training_inputs[n], training_classes, cv=3, train_sizes=np.linspace(.1, .4, 6))
    nn_learning_curve_dict[n] = {'lc_output' : lc_output, 'time': time.time() - start }
    print nn_learning_curve_dict[n]
print ""
print nn_learning_curve_dict

# %%
from sknn.mlp import Classifier, Layer
from sklearn.grid_search import RandomizedSearchCV
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
import time

nn = Classifier(layers=[Layer('Rectifier'),Layer("Softmax")], n_iter=100)

rs = RandomizedSearchCV(nn, param_distributions={
    'learning_rate': stats.uniform(0.001, 0.1),
    'hidden0__units': stats.randint(200, 1500),
    'hidden0__type': ["Rectifier"],
    'regularize':["", 'L2']}, n_jobs=-1)

print nn

print "n_dimensions\ttime\tscore\tparameters"

for n in sorted(svd_training_inputs.keys()):
    nn_train_inputs, nn_test_inputs, nn_train_classes, nn_test_classes = train_test_split(svd_training_inputs[n], training_classes, random_state=42, train_size=500, test_size=500)
    nn_train_inputs = MinMaxScaler().fit_transform(nn_train_inputs)
#     print nn_train_inputs.shape
#     print nn_train_classes.shape
    start = time.time()
    rs.fit(nn_train_inputs, nn_train_classes)
    print"{}\t{}\t{}\t{}".format(n, time.time() - start, rs.best_score_, rs.best_params_)
# Out:
# Classifier(batch_size=1, debug=False, dropout_rate=None, f_stable=0.001,
#       hidden0=<sknn.nn.Layer `Rectifier`: name=u'hidden0'>,
#       layers=[<sknn.nn.Layer `Rectifier`: name=u'hidden0'>, <sknn.nn.Layer `Softmax`: name=u'output'>],
#       learning_momentum=0.9, learning_rate=0.01, learning_rule=u'sgd',
#       loss_type=u'mse', mutator=None, n_iter=100, n_stable=50,
#       output=<sknn.nn.Layer `Softmax`: name=u'output'>, random_state=None,
#       regularize=None, valid_set=None, valid_size=0.0, verbose=None,
#       weight_decay=None)
# n_dimensions	time	score	parameters
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-4c21c11aa40b> in <module>()
#      24 #     print nn_train_classes.shape
#      25     start = time.time()
# ---> 26     rs.fit(nn_train_inputs, nn_train_classes)
#      27     print"{}\t{}\t{}\t{}".format(n, time.time() - start, rs.best_score_, rs.best_params_)
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/sklearn/grid_search.pyc in fit(self, X, y)
#     896                                           self.n_iter,
#     897                                           random_state=self.random_state)
# --> 898         return self._fit(X, y, sampled_params)
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/sklearn/grid_search.pyc in _fit(self, X, y, parameter_iterable)
#     503                                     self.fit_params, return_parameters=True,
#     504                                     error_score=self.error_score)
# --> 505                 for parameters in parameter_iterable
#     506                 for train, test in cv)
#     507
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     664                 # consumption.
#     665                 self._iterating = False
# --> 666             self.retrieve()
#     667             # Make sure that we get a last message telling us we are done
#     668             elapsed_time = time.time() - self._start_time
#
# /home/dadmin/anaconda/envs/supervised/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in retrieve(self)
#     530                             # We can now allow subprocesses again
#     531                             os.environ.pop('__JOBLIB_SPAWNED_PARALLEL__', 0)
# --> 532                         raise exception
#     533                     elif isinstance(exception, TransportableException):
#     534                         # Capture exception to add information on the local
#
# KeyboardInterrupt:

# %%
from learning_curve_helpers import make_learning_curve, plot_learning_curve_from_learning_curve_data
import numpy as np

nn = Classifier(layers=[Layer('Rectifier', units=435),Layer("Softmax")], n_iter=100, regularize="L2", learning_rate=0.0042)

nn_train_inputs, nn_test_inputs, nn_train_classes, nn_test_classes = train_test_split(svd_training_inputs[100], training_classes, random_state=42, train_size=10000, test_size=500)

nn_train_inputs = MinMaxScaler().fit_transform(nn_train_inputs)

# %time dt_lc_output = make_learning_curve(nn, nn_train_inputs, nn_train_classes, cv=3, train_sizes=np.linspace(.1, 1.0, 10))
# Out:
# CPU times: user 900 ms, sys: 864 ms, total: 1.76 s
# Wall time: 12min 38s

# %%
ab_lc_plot = plot_learning_curve_from_learning_curve_data('Neural Net Decision Tree Learning Curve', *dt_lc_output)
# Out:
# train test sizes: [ 666 1332 1998 2664 3330 3996 4662 5328 5994 6660]
# train scores means: [ 0.79229229  0.78878879  0.76176176  0.74199199  0.71411411  0.72931265
#   0.72122122  0.71546547  0.72250028  0.70705706]
# train scores std: [ 0.01981881  0.00035391  0.00566252  0.00920159  0.01471369  0.01977382
#   0.00886543  0.00351132  0.01568432  0.01220996]
# test scores mean: [ 0.53101501  0.58119982  0.60280279  0.60749388  0.60646423  0.632516
#   0.63829479  0.64128828  0.6489979   0.64000681]
# test scores std: [ 0.01256458  0.00719657  0.00449509  0.00875052  0.02397125  0.01441537
#   0.00915161  0.01276271  0.00271117  0.00838384]

# %%
import pickle
with open ('nn_100d_435hidden_learning_curve', 'wb') as d_file:
    pickle.dump(dt_lc_output, d_file)

# %%
from scipy import stats
from sknn.mlp import Classifier, Layer  


nn = Classifier(layers=[Layer('Rectifier'),Layer("Softmax")], n_iter=25)

rs = RandomizedSearchCV(nn, param_distributions={
    'learning_rate': stats.uniform(0.001, 0.05),
    'hidden0__units': stats.randint(100, 500),
    'hidden0__type': ["Rectifier"],
    'regularize':[""]}, n_jobs=-1)

# %time rs.fit(nn_training_inputs, nn_training_classes)

print('Best score: {}'.format(rs.best_score_))
print('Best parameters: {}'.format(rs.best_params_))

# %%
# %history
# Out:
# ## loader adapted from https://kaggle2.blob.core.windows.net/forum-message-attachments/92129/2925/cook.py?sv=2012-02-12&se=2015-09-17T07%3A33%3A08Z&sr=b&sp=r&sig=L0O70df70vhU2ZTBu%2FanG9mafzDdeiVhFaAx0dkscfc%3D
#
# import json
# from pandas import DataFrame
# from collections import OrderedDict
# from sklearn.preprocessing import LabelEncoder
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.feature_extraction.text import CountVectorizer
#
# with open('./data/whats_cookin/train.json') as train_f:
#     train_data = json.load(train_f)
#
# train_X = [' '.join(e['ingredients']) for e in train_data]
# train_Y = [e['cuisine'] for e in train_data]
#
# le = LabelEncoder()
# ngram_vectorizer = CountVectorizer()
#
# all_classes = le.fit_transform(train_Y)
# all_inputs = ngram_vectorizer.fit_transform(train_X).toarray()
# from sklearn.cross_validation import train_test_split
#
# (training_inputs,
#  testing_inputs,
#  training_classes,
#  testing_classes) = train_test_split(all_inputs, all_classes, train_size=0.9)
# from sklearn.decomposition import TruncatedSVD
#
# %time svd_dict = { n:PCA(n_components=n).fit(all_inputs) for n in [10,20,40,100,500,1000,2000] }
# from sklearn.decomposition import TruncatedSVD
#
# %time svd_dict = { n:TruncatedSVD(n_components=n).fit(all_inputs) for n in [10,20,40,100,500,1000,2000] }
# from sklearn.decomposition import TruncatedSVD
#
# %time svd_dict = { n:TruncatedSVD(n_components=n).fit(all_inputs) for n in [50,100,200,300,500] }
# import pickle
#
# with open('recipe_SVD', 'wb') as p_file:
#     pickle.dump(svd_dict, p_file)
# svd_dict
# svd_dict[50]
# svd_dict[50].explained_variance_ratio
# svd_dict[50].explained_variance_ratio_
# for n in svd_dict:
#     print svd_dict[n].explained_variance_ratio_
# print "n_components\tpercentage of variance explained"
# for n in svd_dict:
#     print "{}\t{}".format(n, svd_dict[n].explained_variance_ratio_.sum())
# print "n_components\tpercentage of variance explained"
# for n in sorted(svd_dict.keys()):
#     print "{}\t{}".format(n, svd_dict[n].explained_variance_ratio_.sum())
# import pickle
#
# with open('recipe_SVD', 'rb') as p_file:
#     svd_dict = pickle.load(p_file)
# svd_dict
# svd_training_inputs = {}
#
# for n in sorted(svd_dict.keys()):
#     svd_training_sets[n] = svd_dict[n].transform(training_inputs)
# svd_training_inputs
# svd_training_inputs = {}
#
# for n in sorted(svd_dict.keys()):
#     svd_training_inputs[n] = svd_dict[n].transform(training_inputs)
# svd_training_inputs
# svd_testing_inputs = {}
#
# for n in sorted(svd_dict.keys()):
#     svd_testing_inputs[n] = svd_dict[n].transform(testing_inputs)
# svd_testing_inputs
# import pickle
#
# with open('recipe_SVD_training_inputs', 'wb') as p_file:
#     pickle.dump(svd_training_inputs, p_file)
# with open('recipe_SVD_testing_inputs', 'wb') as p_file:
#     pickle.dump(svd_testing_inputs, p_file)
# import pickle
#
# with open('recipe_SVD_training_inputs', 'rb') as p_file:
#     svd_training_inputs = pickle.load(p_file)
# with open('recipe_SVD_testing_inputs', 'rb') as p_file:
#     svd_testing_inputs = pickle.load(p_file)
# from sknn.mlp import Classifier, Layer
# from sklearn.grid_search import RandomizedSearchCV
# from sklearn.cross_validation import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from scipy import stats
#
#
# for n in sorted(svd_training_inputs.keys()):
#     nn_train_inputs, nn_train_classes, nn_test_inputs, nn_test_classes =
#         train_test_split(svd_training_inputs[n], training_classes, n_train=200, n_test=100)
#     nn_train_inputs = MinMaxScaler().fit_transform(nn_training_inputs)
#     print nn_training_inputs
# from sknn.mlp import Classifier, Layer
# from sklearn.grid_search import RandomizedSearchCV
# from sklearn.cross_validation import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from scipy import stats
#
#
# for n in sorted(svd_training_inputs.keys()):
#     nn_train_inputs, nn_train_classes, nn_test_inputs, nn_test_classes = train_test_split(svd_training_inputs[n], training_classes, n_train=200, n_test=100)
#     nn_train_inputs = MinMaxScaler().fit_transform(nn_training_inputs)
#     print nn_training_inputs
# from sknn.mlp import Classifier, Layer
# from sklearn.grid_search import RandomizedSearchCV
# from sklearn.cross_validation import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from scipy import stats
#
#
# for n in sorted(svd_training_inputs.keys()):
#     nn_train_inputs, nn_train_classes, nn_test_inputs, nn_test_classes = train_test_split(svd_training_inputs[n], training_classes, train_size=200, test_size=100)
#     nn_train_inputs = MinMaxScaler().fit_transform(nn_training_inputs)
#     print nn_training_inputs
# from sknn.mlp import Classifier, Layer
# from sklearn.grid_search import RandomizedSearchCV
# from sklearn.cross_validation import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from scipy import stats
#
#
# for n in sorted(svd_training_inputs.keys()):
#     nn_train_inputs, nn_train_classes, nn_test_inputs, nn_test_classes = train_test_split(svd_training_inputs[n], training_classes, train_size=200, test_size=100)
#     nn_train_inputs = MinMaxScaler().fit_transform(nn_train_inputs)
#     print nn_training_inputs
# from sknn.mlp import Classifier, Layer
# from sklearn.grid_search import RandomizedSearchCV
# from sklearn.cross_validation import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from scipy import stats
#
#
# for n in sorted(svd_training_inputs.keys()):
#     nn_train_inputs, nn_train_classes, nn_test_inputs, nn_test_classes = train_test_split(svd_training_inputs[n], training_classes, train_size=200, test_size=100)
#     nn_train_inputs = MinMaxScaler().fit_transform(nn_train_inputs)
#     print nn_train_inputs
# from sknn.mlp import Classifier, Layer
# from sklearn.grid_search import RandomizedSearchCV
# from sklearn.cross_validation import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from scipy import stats
#
# nn = Classifier(layers=[Layer('Rectifier'),Layer("Softmax")], n_iter=25)
#
# rs = RandomizedSearchCV(nn, param_distributions={
#     'learning_rate': stats.uniform(0.001, 0.05),
#     'hidden0__units': stats.randint(100, 1000),
#     'hidden0__type': ["Rectifier"],
#     'regularize':["", 'L2']}, n_jobs=-1)
#
# print nn
#
# print "n_dimensions\tscore\tparameters"
#
# for n in sorted(svd_training_inputs.keys()):
#     nn_train_inputs, nn_train_classes, nn_test_inputs, nn_test_classes = train_test_split(svd_training_inputs[n], training_classes, train_size=200, test_size=100)
#     nn_train_inputs = MinMaxScaler().fit_transform(nn_train_inputs)
#     %time rs.fit(nn_train_inputs, nn_train_classes)
#     print"{}\t{}\t{}".format(n, rs.best_score, rs.best_params_)
# from sknn.mlp import Classifier, Layer
# from sklearn.grid_search import RandomizedSearchCV
# from sklearn.cross_validation import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from scipy import stats
#
# nn = Classifier(layers=[Layer('Rectifier'),Layer("Softmax")], n_iter=25)
#
# rs = RandomizedSearchCV(nn, param_distributions={
#     'learning_rate': stats.uniform(0.001, 0.05),
#     'hidden0__units': stats.randint(100, 1000),
#     'hidden0__type': ["Rectifier"],
#     'regularize':["", 'L2']}, n_jobs=-1)
#
# print nn
#
# print "n_dimensions\tscore\tparameters"
#
# for n in sorted(svd_training_inputs.keys()):
#     nn_train_inputs, nn_train_classes, nn_test_inputs, nn_test_classes = train_test_split(svd_training_inputs[n], training_classes, train_size=200, test_size=100)
#     nn_train_inputs = MinMaxScaler().fit_transform(nn_train_inputs)
#     %time rs.fit(nn_train_inputs, nn_train_classes)
#     print"{}\t{}\t{}".format(n, rs.best_score, rs.best_params_)
# from sknn.mlp import Classifier, Layer
# from sklearn.grid_search import RandomizedSearchCV
# from sklearn.cross_validation import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from scipy import stats
#
# nn = Classifier(layers=[Layer('Rectifier'),Layer("Softmax")], n_iter=25)
#
# rs = RandomizedSearchCV(nn, param_distributions={
#     'learning_rate': stats.uniform(0.001, 0.05),
#     'hidden0__units': stats.randint(100, 1000),
#     'hidden0__type': ["Rectifier"],
#     'regularize':["", 'L2']}, n_jobs=-1)
#
# print nn
#
# print "n_dimensions\tscore\tparameters"
#
# for n in sorted(svd_training_inputs.keys()):
#     nn_train_inputs, nn_train_classes, nn_test_inputs, nn_test_classes = train_test_split(svd_training_inputs[n], training_classes, train_size=200, test_size=100)
#     nn_train_inputs = MinMaxScaler().fit_transform(nn_train_inputs)
#     rs.fit(nn_train_inputs, nn_train_classes)
#     print"{}\t{}\t{}".format(n, rs.best_score, rs.best_params_)
# svd_training_inputs = {}
#
# for n in sorted(svd_dict.keys()):
#     svd_training_inputs[n] = svd_dict[n].transform(training_inputs)
#     print svd_training_inputs[n].shape
# svd_training_inputs
# svd_training_inputs = {}
#
# for n in sorted(svd_dict.keys()):
#     svd_training_inputs[n] = svd_dict[n].transform(training_inputs)
#     print svd_training_inputs[n].shape
#     print svd_training_inputs[n][1,:].shape
# svd_training_inputs
# from sknn.mlp import Classifier, Layer
# from sklearn.grid_search import RandomizedSearchCV
# from sklearn.cross_validation import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from scipy import stats
#
# nn = Classifier(layers=[Layer('Rectifier'),Layer("Softmax")], n_iter=25)
#
# rs = RandomizedSearchCV(nn, param_distributions={
#     'learning_rate': stats.uniform(0.001, 0.05),
#     'hidden0__units': stats.randint(100, 1000),
#     'hidden0__type': ["Rectifier"],
#     'regularize':["", 'L2']}, n_jobs=-1)
#
# print nn
#
# print "n_dimensions\tscore\tparameters"
#
# for n in sorted(svd_training_inputs.keys()):
#     nn_train_inputs, nn_train_classes, nn_test_inputs, nn_test_classes = train_test_split(svd_training_inputs[n], training_classes, train_size=200, test_size=100)
#     nn_train_inputs = MinMaxScaler().fit_transform(nn_train_inputs)
#     print nn_train_inputs.shape
#     print nn_train_classed.shape
#     rs.fit(nn_train_inputs, nn_train_classes)
#     print"{}\t{}\t{}".format(n, rs.best_score, rs.best_params_)
# from sknn.mlp import Classifier, Layer
# from sklearn.grid_search import RandomizedSearchCV
# from sklearn.cross_validation import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from scipy import stats
#
# nn = Classifier(layers=[Layer('Rectifier'),Layer("Softmax")], n_iter=25)
#
# rs = RandomizedSearchCV(nn, param_distributions={
#     'learning_rate': stats.uniform(0.001, 0.05),
#     'hidden0__units': stats.randint(100, 1000),
#     'hidden0__type': ["Rectifier"],
#     'regularize':["", 'L2']}, n_jobs=-1)
#
# print nn
#
# print "n_dimensions\tscore\tparameters"
#
# for n in sorted(svd_training_inputs.keys()):
#     nn_train_inputs, nn_train_classes, nn_test_inputs, nn_test_classes = train_test_split(svd_training_inputs[n], training_classes, train_size=200, test_size=100)
#     nn_train_inputs = MinMaxScaler().fit_transform(nn_train_inputs)
#     print nn_train_inputs.shape
#     print nn_train_classes.shape
#     rs.fit(nn_train_inputs, nn_train_classes)
#     print"{}\t{}\t{}".format(n, rs.best_score, rs.best_params_)
# from sknn.mlp import Classifier, Layer
# from sklearn.grid_search import RandomizedSearchCV
# from sklearn.cross_validation import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from scipy import stats
#
# nn = Classifier(layers=[Layer('Rectifier'),Layer("Softmax")], n_iter=25)
#
# rs = RandomizedSearchCV(nn, param_distributions={
#     'learning_rate': stats.uniform(0.001, 0.05),
#     'hidden0__units': stats.randint(100, 1000),
#     'hidden0__type': ["Rectifier"],
#     'regularize':["", 'L2']}, n_jobs=-1)
#
# print nn
#
# print "n_dimensions\ttime\tscore\tparameters"
#
# for n in sorted(svd_training_inputs.keys()):
#     nn_train_inputs, nn_test_inputs, nn_train_classes, nn_test_classes = train_test_split(svd_training_inputs[n], training_classes, train_size=200, test_size=100)
#     nn_train_inputs = MinMaxScaler().fit_transform(nn_train_inputs)
# #     print nn_train_inputs.shape
# #     print nn_train_classes.shape
#     start = time.time()
#     rs.fit(nn_train_inputs, nn_train_classes)
#     print"{}\t{}\t{}\t{}".format(n, time.time() - start, rs.best_score, rs.best_params_)
# from sknn.mlp import Classifier, Layer
# from sklearn.grid_search import RandomizedSearchCV
# from sklearn.cross_validation import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from scipy import stats
# import time
#
# nn = Classifier(layers=[Layer('Rectifier'),Layer("Softmax")], n_iter=25)
#
# rs = RandomizedSearchCV(nn, param_distributions={
#     'learning_rate': stats.uniform(0.001, 0.05),
#     'hidden0__units': stats.randint(100, 1000),
#     'hidden0__type': ["Rectifier"],
#     'regularize':["", 'L2']}, n_jobs=-1)
#
# print nn
#
# print "n_dimensions\ttime\tscore\tparameters"
#
# for n in sorted(svd_training_inputs.keys()):
#     nn_train_inputs, nn_test_inputs, nn_train_classes, nn_test_classes = train_test_split(svd_training_inputs[n], training_classes, train_size=200, test_size=100)
#     nn_train_inputs = MinMaxScaler().fit_transform(nn_train_inputs)
# #     print nn_train_inputs.shape
# #     print nn_train_classes.shape
#     start = time.time()
#     rs.fit(nn_train_inputs, nn_train_classes)
#     print"{}\t{}\t{}\t{}".format(n, time.time() - start, rs.best_score, rs.best_params_)
# from sknn.mlp import Classifier, Layer
# from sklearn.grid_search import RandomizedSearchCV
# from sklearn.cross_validation import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from scipy import stats
# import time
#
# nn = Classifier(layers=[Layer('Rectifier'),Layer("Softmax")], n_iter=25)
#
# rs = RandomizedSearchCV(nn, param_distributions={
#     'learning_rate': stats.uniform(0.001, 0.05),
#     'hidden0__units': stats.randint(100, 1000),
#     'hidden0__type': ["Rectifier"],
#     'regularize':["", 'L2']}, n_jobs=-1)
#
# print nn
#
# print "n_dimensions\ttime\tscore\tparameters"
#
# for n in sorted(svd_training_inputs.keys()):
#     nn_train_inputs, nn_test_inputs, nn_train_classes, nn_test_classes = train_test_split(svd_training_inputs[n], training_classes, train_size=500, test_size=100)
#     nn_train_inputs = MinMaxScaler().fit_transform(nn_train_inputs)
# #     print nn_train_inputs.shape
# #     print nn_train_classes.shape
#     start = time.time()
#     rs.fit(nn_train_inputs, nn_train_classes)
#     print"{}\t{}\t{}\t{}".format(n, time.time() - start, rs.best_score_, rs.best_params_)
# from sknn.mlp import Classifier, Layer
# from sklearn.grid_search import RandomizedSearchCV
# from sklearn.cross_validation import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from scipy import stats
# import time
#
# nn = Classifier(layers=[Layer('Rectifier'),Layer("Softmax")], n_iter=100)
#
# rs = RandomizedSearchCV(nn, param_distributions={
#     'learning_rate': stats.uniform(0.001, 0.1),
#     'hidden0__units': stats.randint(200, 1500),
#     'hidden0__type': ["Rectifier"],
#     'regularize':["", 'L2']}, n_jobs=-1)
#
# print nn
#
# print "n_dimensions\ttime\tscore\tparameters"
#
# for n in sorted(svd_training_inputs.keys()):
#     nn_train_inputs, nn_test_inputs, nn_train_classes, nn_test_classes = train_test_split(svd_training_inputs[n], training_classes, train_size=500, test_size=100)
#     nn_train_inputs = MinMaxScaler().fit_transform(nn_train_inputs)
# #     print nn_train_inputs.shape
# #     print nn_train_classes.shape
#     start = time.time()
#     rs.fit(nn_train_inputs, nn_train_classes)
#     print"{}\t{}\t{}\t{}".format(n, time.time() - start, rs.best_score_, rs.best_params_)
# from sknn.mlp import Classifier, Layer
# from sklearn.grid_search import RandomizedSearchCV
# from sklearn.cross_validation import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from scipy import stats
# import time
#
# nn = Classifier(layers=[Layer('Rectifier'),Layer("Softmax")], n_iter=100)
#
# rs = RandomizedSearchCV(nn, param_distributions={
#     'learning_rate': stats.uniform(0.001, 0.1),
#     'hidden0__units': stats.randint(200, 1500),
#     'hidden0__type': ["Rectifier"],
#     'regularize':["", 'L2']}, n_jobs=-1)
#
# print nn
#
# print "n_dimensions\ttime\tscore\tparameters"
#
# for n in sorted(svd_training_inputs.keys()):
#     nn_train_inputs, nn_test_inputs, nn_train_classes, nn_test_classes = train_test_split(svd_training_inputs[n], training_classes, random_seed=42, train_size=500, test_size=500)
#     nn_train_inputs = MinMaxScaler().fit_transform(nn_train_inputs)
# #     print nn_train_inputs.shape
# #     print nn_train_classes.shape
#     start = time.time()
#     rs.fit(nn_train_inputs, nn_train_classes)
#     print"{}\t{}\t{}\t{}".format(n, time.time() - start, rs.best_score_, rs.best_params_)
# from sknn.mlp import Classifier, Layer
# from sklearn.grid_search import RandomizedSearchCV
# from sklearn.cross_validation import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from scipy import stats
# import time
#
# nn = Classifier(layers=[Layer('Rectifier'),Layer("Softmax")], n_iter=100)
#
# rs = RandomizedSearchCV(nn, param_distributions={
#     'learning_rate': stats.uniform(0.001, 0.1),
#     'hidden0__units': stats.randint(200, 1500),
#     'hidden0__type': ["Rectifier"],
#     'regularize':["", 'L2']}, n_jobs=-1)
#
# print nn
#
# print "n_dimensions\ttime\tscore\tparameters"
#
# for n in sorted(svd_training_inputs.keys()):
#     nn_train_inputs, nn_test_inputs, nn_train_classes, nn_test_classes = train_test_split(svd_training_inputs[n], training_classes, random_state=42, train_size=500, test_size=500)
#     nn_train_inputs = MinMaxScaler().fit_transform(nn_train_inputs)
# #     print nn_train_inputs.shape
# #     print nn_train_classes.shape
#     start = time.time()
#     rs.fit(nn_train_inputs, nn_train_classes)
#     print"{}\t{}\t{}\t{}".format(n, time.time() - start, rs.best_score_, rs.best_params_)
# ## loader adapted from https://kaggle2.blob.core.windows.net/forum-message-attachments/92129/2925/cook.py?sv=2012-02-12&se=2015-09-17T07%3A33%3A08Z&sr=b&sp=r&sig=L0O70df70vhU2ZTBu%2FanG9mafzDdeiVhFaAx0dkscfc%3D
#
# import json
# from pandas import DataFrame
# from collections import OrderedDict
# from sklearn.preprocessing import LabelEncoder
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.feature_extraction.text import CountVectorizer
# import numpy as np
#
# np.random.set_state(42)
#
#
# with open('./data/whats_cookin/train.json') as train_f:
#     train_data = json.load(train_f)
#
# train_X = [' '.join(e['ingredients']) for e in train_data]
# train_Y = [e['cuisine'] for e in train_data]
#
# le = LabelEncoder()
# ngram_vectorizer = CountVectorizer()
#
# all_classes = le.fit_transform(train_Y)
# all_inputs = ngram_vectorizer.fit_transform(train_X).toarray()
# from learning_curve_helpers import make_learning_curve, plot_learning_curve_from_learning_curve_data
# import numpy as np
#
# nn = Classifier(layers=[Layer('Rectifier', units=435),Layer("Softmax")], n_iter=100, regularize="L2", learning_rate=0.0042)
#
# nn_train_inputs, nn_test_inputs, nn_train_classes, nn_test_classes = train_test_split(svd_training_inputs[100], training_classes, random_state=42, train_size=2000, test_size=500)
#
# %time dt_lc_output = make_learning_curve(nn, nn_train_inputs, nn_train_classes, cv=3, train_sizes=np.linspace(.1, 1.0, 5))
# from learning_curve_helpers import make_learning_curve, plot_learning_curve_from_learning_curve_data
# import numpy as np
#
# nn = Classifier(layers=[Layer('Rectifier', units=435),Layer("Softmax")], n_iter=100, regularize="L2", learning_rate=0.0042)
#
# nn_train_inputs, nn_test_inputs, nn_train_classes, nn_test_classes = train_test_split(svd_training_inputs[100], training_classes, random_state=42, train_size=10000, test_size=500)
#
# nn_train_inputs = MinMaxScaler().fit_transform(nn_train_inputs)
#
# %time dt_lc_output = make_learning_curve(nn, nn_train_inputs, nn_train_classes, cv=3, train_sizes=np.linspace(.1, 1.0, 10))
# ## loader adapted from https://kaggle2.blob.core.windows.net/forum-message-attachments/92129/2925/cook.py?sv=2012-02-12&se=2015-09-17T07%3A33%3A08Z&sr=b&sp=r&sig=L0O70df70vhU2ZTBu%2FanG9mafzDdeiVhFaAx0dkscfc%3D
#
# import json
# from pandas import DataFrame
# from collections import OrderedDict
# from sklearn.preprocessing import LabelEncoder
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.feature_extraction.text import CountVectorizer
# import numpy as np
#
# np.random.ramdomState.set_state(42)
#
#
# with open('./data/whats_cookin/train.json') as train_f:
#     train_data = json.load(train_f)
#
# train_X = [' '.join(e['ingredients']) for e in train_data]
# train_Y = [e['cuisine'] for e in train_data]
#
# le = LabelEncoder()
# ngram_vectorizer = CountVectorizer()
#
# all_classes = le.fit_transform(train_Y)
# all_inputs = ngram_vectorizer.fit_transform(train_X).toarray()
# import os
# print(os.getcwd())
# %matplotlib inline
# np.random.seed(42)
# import numpy as np
# import os
# print(os.getcwd())
# %matplotlib inline
# np.random.seed(42)
# ## loader adapted from https://kaggle2.blob.core.windows.net/forum-message-attachments/92129/2925/cook.py?sv=2012-02-12&se=2015-09-17T07%3A33%3A08Z&sr=b&sp=r&sig=L0O70df70vhU2ZTBu%2FanG9mafzDdeiVhFaAx0dkscfc%3D
#
# import json
# from pandas import DataFrame
# from collections import OrderedDict
# from sklearn.preprocessing import LabelEncoder
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.feature_extraction.text import CountVectorizer
# import numpy as np
#
#
#
#
# with open('./data/whats_cookin/train.json') as train_f:
#     train_data = json.load(train_f)
#
# train_X = [' '.join(e['ingredients']) for e in train_data]
# train_Y = [e['cuisine'] for e in train_data]
#
# le = LabelEncoder()
# ngram_vectorizer = CountVectorizer()
#
# all_classes = le.fit_transform(train_Y)
# all_inputs = ngram_vectorizer.fit_transform(train_X).toarray()
# train_X_list
# #[item for sublist in l for item in sublist]
# train_X_list = [ ingredient for e in train_data for ingredient in e['ingredients'] ]
# len(sorted(list(set(train_X_list))))
# train_X_list
# print('Feature set shape: {}'.format(all_inputs.shape))
# print('Class set shape: {}'.format(all_classes.shape))
# len(le.classes_)
# set(train_Y)
# set(train_X)
# #### Create main test and training data sets
# from sklearn.cross_validation import train_test_split
#
# (training_inputs,
#  testing_inputs,
#  training_classes,
#  testing_classes) = train_test_split(all_inputs, all_classes, train_size=0.9)
# #### Create LSA matrix aka TruncatedSVD
# LSA is a dimensional reduction decomposition that works well with sparse feature vectors such as out vector of recipe
# ingredient vectors.
# from sklearn.decomposition import TruncatedSVD
#
# %time svd_dict = { n:TruncatedSVD(n_components=n).fit(all_inputs) for n in [50,100,200,300,500,750,1000] }
# import pickle
#
# with open('recipe_SVD', 'wb') as p_file:
#     pickle.dump(svd_dict, p_file)
# import pickle
#
# with open('recipe_SVD', 'rb') as p_file:
#     svd_dict = pickle.load(p_file)
# svd_dict
# for n in svd_dict:
#     print svd_dict[n].explained_variance_ratio_
# print "n_components\tpercentage of variance explained"
# for n in sorted(svd_dict.keys()):
#     print "{}\t{}".format(n, svd_dict[n].explained_variance_ratio_.sum())
# import pickle
#
# with open('recipe_SVD_training_inputs', 'wb') as p_file:
#     pickle.dump(svd_training_inputs, p_file)
# with open('recipe_SVD_testing_inputs', 'wb') as p_file:
#     pickle.dump(svd_testing_inputs, p_file)
# import pickle
#
# with open('recipe_SVD_training_inputs', 'rb') as p_file:
#     svd_training_inputs = pickle.load(p_file)
# with open('recipe_SVD_testing_inputs', 'rb') as p_file:
#     svd_testing_inputs = pickle.load(p_file)
# svd_training_inputs = {}
#
# for n in sorted(svd_dict.keys()):
#     svd_training_inputs[n] = svd_dict[n].transform(training_inputs)
#     print svd_training_inputs[n].shape
#     print svd_training_inputs[n][1,:].shape
# svd_training_inputs
# #### generate SVD training inputs
# svd_training_inputs = {}
#
# for n in sorted(svd_dict.keys()):
#     svd_training_inputs[n] = svd_dict[n].transform(training_inputs)
#     print svd_training_inputs[n].shape
#     print svd_training_inputs[n][1,:].shape
# svd_testing_inputs = {}
#
# for n in sorted(svd_dict.keys()):
#     svd_testing_inputs[n] = svd_dict[n].transform(testing_inputs)
#     print svd_testing_inputs[n].shape
#     print svd_testing_inputs[n][1,:].shape
# ?
# import pickle
#
# with open('recipe_SVD_training_inputs', 'rb') as p_file:
#     svd_training_inputs = pickle.load(p_file)
# with open('recipe_SVD_testing_inputs', 'rb') as p_file:
#     svd_testing_inputs = pickle.load(p_file)
# import pickle
#
# with open('recipe_SVD_training_inputs', 'wb') as p_file:
#     pickle.dump(svd_training_inputs, p_file)
# with open('recipe_SVD_testing_inputs', 'wb') as p_file:
#     pickle.dump(svd_testing_inputs, p_file)
# from sknn.mlp import Classifier, Layer
# from sklearn.grid_search import RandomizedSearchCV
# from sklearn.cross_validation import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from scipy import stats
# import time
#
# nn = Classifier(layers=[Layer('Rectifier'),Layer("Softmax")], n_iter=25)
#
# rs = RandomizedSearchCV(nn, param_distributions={
#     'learning_rate': stats.uniform(0.001, 0.05),
#     'hidden0__units': stats.randint(100, 2000),
#     'hidden0__type': ["Rectifier"],
#     'regularize':["", 'L2']}, n_jobs=-1)
#
# print nn
#
# print "n_dimensions\ttime\tscore\tparameters"
#
# for n in sorted(svd_training_inputs.keys()):
#     nn_train_inputs, nn_test_inputs, nn_train_classes, nn_test_classes = train_test_split(svd_training_inputs[n], training_classes, train_size=500, test_size=100)
#     nn_train_inputs = MinMaxScaler().fit_transform(nn_train_inputs)
# #     print nn_train_inputs.shape
# #     print nn_train_classes.shape
#     start = time.time()
#     rs.fit(nn_train_inputs, nn_train_classes)
#     print"{}\t{}\t{}\t{}".format(n, time.time() - start, rs.best_score_, rs.best_params_)
# ab_lc_plot = plot_learning_curve_from_learning_curve_data('Neural Net Decision Tree Learning Curve', *dt_lc_output)
# import pickle
# with open ('nn_100d_435hidden_learning_curve', 'wb') as d_file:
#     pickle.dump(dt_lc_output, d_file)
# %history

# %% [markdown]
# ### K nearest neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cross_validation import train_test_split

train_in, test_in, train_out, test_out = train_test_split(norm_svd_training_inputs[100], training_classes, train_size=500, test_size=500 random_state=42)

print train_in.shape
print test_in.shape

classifier = KNeighborsClassifier(n_neighbors=20)
# %time classifier.fit(train_in, train_out)
train_score = classifier.score(train_in, train_out)
test_score = classifier.score(train_in, train_out)

print train_score
print_test_score
